# %% [markdown]
# # Assignment 4
# ## Advancing on assignment 3

# %% [markdown]
# ### In assignment 3, I produced a map based off the census tracts but I was unable to figure out how to map beyond the basics.
# ### In assignment 4, I will figure out how to plot the data into the maps

# %%
# libraries
import pandas as pd
import numpy as np
import geopandas as gpd

# to give more power to my figures (plots)
import matplotlib.pyplot as plt

import contextily as ctx

# to download osm data
import osmnx as ox

# for interactive plots
import plotly.express as px

# %%
df1collisions1419 = pd.read_csv("Collisions_2014-2019_(SWITRS).csv")

# %%
df1collisions1419
# Out:
#                 X          Y  OBJECTID  case_id  accident_year  \
# 0     -118.246279  33.938110         1  9176219           2019
# 1     -118.525004  34.259102        42  8785812           2019
# 2        0.000000   0.000000        43  8792741           2019
# 3     -118.365862  34.072124        44  8837011           2019
# 4     -118.327175  34.023483        45  8798825           2019
# ...           ...        ...       ...      ...            ...
# 37554 -118.268042  34.040627    195479  8926369           2019
# 37555 -118.242992  34.080387    196090  8923047           2019
# 37556 -118.550012  34.039474    196091  8924070           2019
# 37557 -118.318252  34.010815    196092  8927892           2019
# 37558 -118.261665  34.080566    196093  8928796           2019
#
#                     proc_date  juris          collision_date  collision_time  \
# 0      2020/12/09 00:00:00+00   1942  2019/10/24 00:00:00+00            1630
# 1      2019/02/02 00:00:00+00   1942  2019/01/16 00:00:00+00            2500
# 2      2019/02/21 00:00:00+00   1942  2019/01/17 00:00:00+00            2500
# 3      2019/04/30 00:00:00+00   1942  2019/01/20 00:00:00+00            2500
# 4      2019/02/21 00:00:00+00   1942  2019/01/23 00:00:00+00            2500
# ...                       ...    ...                     ...             ...
# 37554  2019/09/05 00:00:00+00   1942  2019/06/28 00:00:00+00            2105
# 37555  2019/08/26 00:00:00+00   1942  2019/06/18 00:00:00+00            2200
# 37556  2019/10/03 00:00:00+00   1942  2019/06/29 00:00:00+00            2145
# 37557  2019/09/13 00:00:00+00   1942  2019/06/26 00:00:00+00            2210
# 37558  2019/09/17 00:00:00+00   1942  2019/06/13 00:00:00+00            2215
#
#        officer_id  ... month_         city       county  state     point_x  \
# 0         43551.0  ...     10  LOS ANGELES  LOS ANGELES     CA -118.246279
# 1         41514.0  ...      1  LOS ANGELES  LOS ANGELES     CA -118.525004
# 2         36733.0  ...      1  LOS ANGELES  LOS ANGELES     CA    0.000000
# 3         43039.0  ...      1  LOS ANGELES  LOS ANGELES     CA -118.365862
# 4         38503.0  ...      1  LOS ANGELES  LOS ANGELES     CA -118.327175
# ...           ...  ...    ...          ...          ...    ...         ...
# 37554     33452.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.268042
# 37555     42202.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.242992
# 37556     42815.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.550012
# 37557     43044.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.318252
# 37558     43813.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.261665
#
#          point_y                                         match_addr  \
# 0      33.938110            COMPTON AVE & 108TH ST, LOS ANGELES, CA
# 1      34.259102          HIAWATHA ST & ZELZAH AVE, LOS ANGELES, CA
# 2       0.000000            RATNER ST & FULTON AVE, LOS ANGELES, CA
# 3      34.072124    CRESCENT HEIGHTS BLVD & 3RD ST, LOS ANGELES, CA
# 4      34.023483                 9TH AVE & 36TH ST, LOS ANGELES, CA
# ...          ...                                                ...
# 37554  34.040627           FIGUEROA ST & PICO BLVD, LOS ANGELES, CA
# 37555  34.080387           ACADEMY RD & ACADEMY DR, LOS ANGELES, CA
# 37556  34.039474  PACIFIC COAST HWY & MALIBU VILLAGE LN, LOS ANG...
# 37557  34.010815  ARLINGTON AVE & MARTIN LUTHER KING JR BLVD, LO...
# 37558  34.080566          ALVARADO ST & MONTANA ST, LOS ANGELES, CA
#
#                  m_primaryrd                  m_secondrd  int_id
# 0                COMPTON AVE                    108TH ST  110153
# 1                HIAWATHA ST                  ZELZAH AVE  108659
# 2                  RATNER ST                  FULTON AVE  136270
# 3      CRESCENT HEIGHTS BLVD                      3RD ST  107485
# 4                    9TH AVE                     36TH ST  148943
# ...                      ...                         ...     ...
# 37554            FIGUEROA ST                   PICO BLVD  117566
# 37555             ACADEMY RD                  ACADEMY DR  121746
# 37556      PACIFIC COAST HWY           MALIBU VILLAGE LN    1859
# 37557          ARLINGTON AVE  MARTIN LUTHER KING JR BLVD  120267
# 37558            ALVARADO ST                  MONTANA ST  128984
#
# [37559 rows x 90 columns]

# %%
df1collisions1419.info
# Out:
# <bound method DataFrame.info of                 X          Y  OBJECTID  case_id  accident_year  \
# 0     -118.246279  33.938110         1  9176219           2019
# 1     -118.525004  34.259102        42  8785812           2019
# 2        0.000000   0.000000        43  8792741           2019
# 3     -118.365862  34.072124        44  8837011           2019
# 4     -118.327175  34.023483        45  8798825           2019
# ...           ...        ...       ...      ...            ...
# 37554 -118.268042  34.040627    195479  8926369           2019
# 37555 -118.242992  34.080387    196090  8923047           2019
# 37556 -118.550012  34.039474    196091  8924070           2019
# 37557 -118.318252  34.010815    196092  8927892           2019
# 37558 -118.261665  34.080566    196093  8928796           2019
#
#                     proc_date  juris          collision_date  collision_time  \
# 0      2020/12/09 00:00:00+00   1942  2019/10/24 00:00:00+00            1630
# 1      2019/02/02 00:00:00+00   1942  2019/01/16 00:00:00+00            2500
# 2      2019/02/21 00:00:00+00   1942  2019/01/17 00:00:00+00            2500
# 3      2019/04/30 00:00:00+00   1942  2019/01/20 00:00:00+00            2500
# 4      2019/02/21 00:00:00+00   1942  2019/01/23 00:00:00+00            2500
# ...                       ...    ...                     ...             ...
# 37554  2019/09/05 00:00:00+00   1942  2019/06/28 00:00:00+00            2105
# 37555  2019/08/26 00:00:00+00   1942  2019/06/18 00:00:00+00            2200
# 37556  2019/10/03 00:00:00+00   1942  2019/06/29 00:00:00+00            2145
# 37557  2019/09/13 00:00:00+00   1942  2019/06/26 00:00:00+00            2210
# 37558  2019/09/17 00:00:00+00   1942  2019/06/13 00:00:00+00            2215
#
#        officer_id  ... month_         city       county  state     point_x  \
# 0         43551.0  ...     10  LOS ANGELES  LOS ANGELES     CA -118.246279
# 1         41514.0  ...      1  LOS ANGELES  LOS ANGELES     CA -118.525004
# 2         36733.0  ...      1  LOS ANGELES  LOS ANGELES     CA    0.000000
# 3         43039.0  ...      1  LOS ANGELES  LOS ANGELES     CA -118.365862
# 4         38503.0  ...      1  LOS ANGELES  LOS ANGELES     CA -118.327175
# ...           ...  ...    ...          ...          ...    ...         ...
# 37554     33452.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.268042
# 37555     42202.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.242992
# 37556     42815.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.550012
# 37557     43044.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.318252
# 37558     43813.0  ...      6  LOS ANGELES  LOS ANGELES     CA -118.261665
#
#          point_y                                         match_addr  \
# 0      33.938110            COMPTON AVE & 108TH ST, LOS ANGELES, CA
# 1      34.259102          HIAWATHA ST & ZELZAH AVE, LOS ANGELES, CA
# 2       0.000000            RATNER ST & FULTON AVE, LOS ANGELES, CA
# 3      34.072124    CRESCENT HEIGHTS BLVD & 3RD ST, LOS ANGELES, CA
# 4      34.023483                 9TH AVE & 36TH ST, LOS ANGELES, CA
# ...          ...                                                ...
# 37554  34.040627           FIGUEROA ST & PICO BLVD, LOS ANGELES, CA
# 37555  34.080387           ACADEMY RD & ACADEMY DR, LOS ANGELES, CA
# 37556  34.039474  PACIFIC COAST HWY & MALIBU VILLAGE LN, LOS ANG...
# 37557  34.010815  ARLINGTON AVE & MARTIN LUTHER KING JR BLVD, LO...
# 37558  34.080566          ALVARADO ST & MONTANA ST, LOS ANGELES, CA
#
#                  m_primaryrd                  m_secondrd  int_id
# 0                COMPTON AVE                    108TH ST  110153
# 1                HIAWATHA ST                  ZELZAH AVE  108659
# 2                  RATNER ST                  FULTON AVE  136270
# 3      CRESCENT HEIGHTS BLVD                      3RD ST  107485
# 4                    9TH AVE                     36TH ST  148943
# ...                      ...                         ...     ...
# 37554            FIGUEROA ST                   PICO BLVD  117566
# 37555             ACADEMY RD                  ACADEMY DR  121746
# 37556      PACIFIC COAST HWY           MALIBU VILLAGE LN    1859
# 37557          ARLINGTON AVE  MARTIN LUTHER KING JR BLVD  120267
# 37558            ALVARADO ST                  MONTANA ST  128984
#
# [37559 rows x 90 columns]>

# %%
gdf = gpd.GeoDataFrame(df1collisions1419, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(df1collisions1419.point_x, df1collisions1419.point_y))

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# # Managed to map the collisions data onto a map

# %%
# start the plot
fig, ax = plt.subplots(figsize=(12,12))

usbounds = [-189,18,-66,71]

# add the data options
ax = gdf.clip([-189,18,-66,71]).plot(ax=ax, 
        marker='X',
        markersize=10,
        color='red')

# turn the axes off
ax.axis('off')

# give it a title
ax.set_title('Collisions in LA - 2014 to 2019')

# add a basemap
ctx.add_basemap(ax, crs=4326) # note that we must specify the projection here (crs)

# %% [markdown]
# # Here, I entered a new file called Collisions Profile Analysis and Prioritization Scores.
# ## This dataset is from 2009 to 2013, developed specifically by the Vision Zero team.
# This is the link: https://geohub.lacity.org/datasets/ladot::collision-profile-analysis-and-prioritization-scores/explore?layer=0&showTable=true

# %%
df2collisionsprofile = gpd.read_file("Collision_Profile_Analysis_and_Prioritization_Scores.geojson")

# %%
df2collisionsprofile
# Out:
#       OBJECTID  FID_ Shape__   CaseID  AssetID      PointX     PointY  \
# 0            1     0   Point  3984274   100055 -118.256090  34.051579
# 1            2     1   Point  3984281   130209 -118.450240  34.227650
# 2            3     2   Point  3984352   114709 -118.304110  34.068981
# 3            4     3   Point  3984369   103365 -118.263633  34.003887
# 4            5     4   Point  4014945   124320 -118.262350  33.778492
# ...        ...   ...     ...      ...      ...         ...        ...
# 2927      2928  2927   Point  6511663   146504 -118.310720  34.101719
# 2928      2929  2928   Point  6718004   142564 -118.344030  34.068878
# 2929      2930  2929   Point  6718469   131765 -118.186950  34.127121
# 2930      2931  2930   Point  6718472   114798 -118.287062  34.063652
# 2931      2932  2931   Point  6378882   134610 -118.254267  33.937306
#
#       AccidentYe  CollisionS PedBikeVeh  ... P9 P10 P11  P12  P13  P14  P15  \
# 0           2009           1          P  ...  0   0   0    0    0    0    0
# 1           2009           1          V  ...  0   0   0    0    0    1    0
# 2           2009           1          V  ...  0   0   0    0    0    0    1
# 3           2009           1          P  ...  0   0   0    0    0    0    0
# 4           2009           1          P  ...  0   0   0    0    0    0    0
# ...          ...         ...        ...  ... ..  ..  ..  ...  ...  ...  ...
# 2927        2013           2          V  ...  0   0   0    0    0    0    0
# 2928        2013           1          P  ...  0   1   0    0    0    0    0
# 2929        2013           1          P  ...  0   0   0    0    0    0    0
# 2930        2013           1          B  ...  0   0   1    0    0    0    0
# 2931        2013           2          B  ...  0   0   0    0    0    0    0
#
#             LAT         LON                     geometry
# 0     34.051566 -118.256081  POINT (-118.25608 34.05157)
# 1     34.226939 -118.449888  POINT (-118.44989 34.22694)
# 2     34.068993 -118.304107  POINT (-118.30411 34.06899)
# 3     34.003891 -118.263955  POINT (-118.26395 34.00389)
# 4     33.778524 -118.262317  POINT (-118.26232 33.77852)
# ...         ...         ...                          ...
# 2927  34.101724 -118.310706  POINT (-118.31071 34.10172)
# 2928  34.068892 -118.344022  POINT (-118.34402 34.06889)
# 2929  34.126715 -118.186763  POINT (-118.18676 34.12672)
# 2930  34.063705 -118.287042  POINT (-118.28704 34.06371)
# 2931  33.936796 -118.254184  POINT (-118.25418 33.93680)
#
# [2932 rows x 51 columns]

# %%
gdf2 = gpd.GeoDataFrame(df2collisionsprofile, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(df2collisionsprofile.PointX, df2collisionsprofile.PointY))

# %%
gdf2.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# start the plot
fig, ax = plt.subplots(figsize=(12,12))

usbounds = [-189,18,-66,71]

# add the data options
ax = gdf2.clip([-189,18,-66,71]).plot(ax=ax, 
        marker='X',
        markersize=10,
        color='red')

# turn the axes off
ax.axis('off')

# give it a title
ax.set_title('Collisions in LA 2009 to 2013')

# add a basemap
ctx.add_basemap(ax, crs=4326) # note that we must specify the projection here (crs)

# %%
plt.savefig('collisions2013_map.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # I found a file from the California Highway Patrol called SWITRS 2019 Report
# <https://www.chp.ca.gov/programs-services/services-information/switrs-internet-statewide-integrated-traffic-records-system/switrs-2019-report>

# %% [markdown]
# ## It is an excel file so I will import pandas and numpys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df1fatalbyage = pd.read_csv("Fatal vehicle drivers by age by impairment.csv")

# %%
df1fatalbyage
# Out:
#      Degree of Alcohol Impairment  0-14  15-20  21-24  25-29  30-34  35-39  \
# 0           HBD - under influence   0.0   37.0  128.0  158.0   94.0   62.0
# 1       HBD - not under influence   0.0    4.0   10.0   10.0   16.0    9.0
# 2        HBD - impairment unknown   0.0    6.0    9.0   11.0   11.0   13.0
# 3                           Total   0.0   47.0  147.0  179.0  121.0   84.0
# 4  Total drivers in fatal crashes   3.0  358.0  497.0  695.0  502.0  426.0
# 5       Percent had been drinking   0.0   13.1   29.6   25.8   24.1   19.7
#
#    40-44  45-49  50-54  55-59  60-64  65 and over  Not stated  Total
# 0   52.0   43.0   29.0   41.0   17.0         19.0         1.0    681
# 1    5.0    7.0    2.0    7.0    3.0         13.0         0.0     86
# 2    5.0    5.0    5.0    6.0    4.0          7.0         2.0     84
# 3   62.0   55.0   36.0   54.0   24.0         39.0         3.0    851
# 4  410.0  420.0  369.0  384.0  308.0        586.0       228.0  5,186
# 5   15.1   13.1    9.8   14.1    7.8          6.7         1.3   16.4

# %% [markdown]
# County level joining
# Google California counties shapefile
# use join code by name, have 2 dataframes, county shapefile and accidents data
# Add accident data in shapefile
# It will include the geometries fo teh counties andv then add another column for january or the total and have county names and geomtries and how many accidents 2019
# Look back at lab for census data, walk me through how to join the data and have the different colors
#
# Search for other data for 2019 collisions, search state level

# %% [markdown]
# ## I want to transpose the data so

# %%
df_transposed = df1fatalbyage_no_total.set_index('Degree of Alcohol Impairment').T

# %%
df_transposed
# Out:
# Degree of Alcohol Impairment HBD - under influence HBD - not under influence  \
# 0-14                                           0.0                       0.0
# 15-20                                         37.0                       4.0
# 21-24                                        128.0                      10.0
# 25-29                                        158.0                      10.0
# 30-34                                         94.0                      16.0
# 35-39                                         62.0                       9.0
# 40-44                                         52.0                       5.0
# 45-49                                         43.0                       7.0
# 50-54                                         29.0                       2.0
# 55-59                                         41.0                       7.0
# 60-64                                         17.0                       3.0
# 65 and over                                   19.0                      13.0
# Not stated                                     1.0                       0.0
# Total                                          681                        86
#
# Degree of Alcohol Impairment HBD - impairment unknown  \
# 0-14                                              0.0
# 15-20                                             6.0
# 21-24                                             9.0
# 25-29                                            11.0
# 30-34                                            11.0
# 35-39                                            13.0
# 40-44                                             5.0
# 45-49                                             5.0
# 50-54                                             5.0
# 55-59                                             6.0
# 60-64                                             4.0
# 65 and over                                       7.0
# Not stated                                        2.0
# Total                                              84
#
# Degree of Alcohol Impairment Total drivers in fatal crashes  \
# 0-14                                                    3.0
# 15-20                                                 358.0
# 21-24                                                 497.0
# 25-29                                                 695.0
# 30-34                                                 502.0
# 35-39                                                 426.0
# 40-44                                                 410.0
# 45-49                                                 420.0
# 50-54                                                 369.0
# 55-59                                                 384.0
# 60-64                                                 308.0
# 65 and over                                           586.0
# Not stated                                            228.0
# Total                                                 5,186
#
# Degree of Alcohol Impairment Percent had been drinking
# 0-14                                               0.0
# 15-20                                             13.1
# 21-24                                             29.6
# 25-29                                             25.8
# 30-34                                             24.1
# 35-39                                             19.7
# 40-44                                             15.1
# 45-49                                             13.1
# 50-54                                              9.8
# 55-59                                             14.1
# 60-64                                              7.8
# 65 and over                                        6.7
# Not stated                                         1.3
# Total                                             16.4

# %% [markdown]
# ## I want to change the label of Degree of Alc impairment, into age because it no longer translate sinto the data.
# ## Also, I want to drop the Total table.

# %%
# Drop the row with index 'Total' under 'Degree of Alcohol Impairment'
df1fatalbyage_no_total = df_transposed.drop('Total')

# %%
# Now I can see there is no Total
df1fatalbyage_no_total
# Out:
# Degree of Alcohol Impairment HBD - under influence HBD - not under influence  \
# 0-14                                           0.0                       0.0
# 15-20                                         37.0                       4.0
# 21-24                                        128.0                      10.0
# 25-29                                        158.0                      10.0
# 30-34                                         94.0                      16.0
# 35-39                                         62.0                       9.0
# 40-44                                         52.0                       5.0
# 45-49                                         43.0                       7.0
# 50-54                                         29.0                       2.0
# 55-59                                         41.0                       7.0
# 60-64                                         17.0                       3.0
# 65 and over                                   19.0                      13.0
# Not stated                                     1.0                       0.0
#
# Degree of Alcohol Impairment HBD - impairment unknown  \
# 0-14                                              0.0
# 15-20                                             6.0
# 21-24                                             9.0
# 25-29                                            11.0
# 30-34                                            11.0
# 35-39                                            13.0
# 40-44                                             5.0
# 45-49                                             5.0
# 50-54                                             5.0
# 55-59                                             6.0
# 60-64                                             4.0
# 65 and over                                       7.0
# Not stated                                        2.0
#
# Degree of Alcohol Impairment Total drivers in fatal crashes  \
# 0-14                                                    3.0
# 15-20                                                 358.0
# 21-24                                                 497.0
# 25-29                                                 695.0
# 30-34                                                 502.0
# 35-39                                                 426.0
# 40-44                                                 410.0
# 45-49                                                 420.0
# 50-54                                                 369.0
# 55-59                                                 384.0
# 60-64                                                 308.0
# 65 and over                                           586.0
# Not stated                                            228.0
#
# Degree of Alcohol Impairment Percent had been drinking
# 0-14                                               0.0
# 15-20                                             13.1
# 21-24                                             29.6
# 25-29                                             25.8
# 30-34                                             24.1
# 35-39                                             19.7
# 40-44                                             15.1
# 45-49                                             13.1
# 50-54                                              9.8
# 55-59                                             14.1
# 60-64                                              7.8
# 65 and over                                        6.7
# Not stated                                         1.3

# %% [markdown]
# ## Now I want to change the label "Degree of Alcohol Impairment" into "Age"

# %%
df1fatalbyage_no_total.rename(columns={'Degree of Alcohol Impairment': 'Age'}, inplace=True)

# %%
df1fatalbyage_no_total
# Out:
# Degree of Alcohol Impairment HBD - under influence HBD - not under influence  \
# 0-14                                           0.0                       0.0
# 15-20                                         37.0                       4.0
# 21-24                                        128.0                      10.0
# 25-29                                        158.0                      10.0
# 30-34                                         94.0                      16.0
# 35-39                                         62.0                       9.0
# 40-44                                         52.0                       5.0
# 45-49                                         43.0                       7.0
# 50-54                                         29.0                       2.0
# 55-59                                         41.0                       7.0
# 60-64                                         17.0                       3.0
# 65 and over                                   19.0                      13.0
# Not stated                                     1.0                       0.0
#
# Degree of Alcohol Impairment HBD - impairment unknown  \
# 0-14                                              0.0
# 15-20                                             6.0
# 21-24                                             9.0
# 25-29                                            11.0
# 30-34                                            11.0
# 35-39                                            13.0
# 40-44                                             5.0
# 45-49                                             5.0
# 50-54                                             5.0
# 55-59                                             6.0
# 60-64                                             4.0
# 65 and over                                       7.0
# Not stated                                        2.0
#
# Degree of Alcohol Impairment Total drivers in fatal crashes  \
# 0-14                                                    3.0
# 15-20                                                 358.0
# 21-24                                                 497.0
# 25-29                                                 695.0
# 30-34                                                 502.0
# 35-39                                                 426.0
# 40-44                                                 410.0
# 45-49                                                 420.0
# 50-54                                                 369.0
# 55-59                                                 384.0
# 60-64                                                 308.0
# 65 and over                                           586.0
# Not stated                                            228.0
#
# Degree of Alcohol Impairment Percent had been drinking
# 0-14                                               0.0
# 15-20                                             13.1
# 21-24                                             29.6
# 25-29                                             25.8
# 30-34                                             24.1
# 35-39                                             19.7
# 40-44                                             15.1
# 45-49                                             13.1
# 50-54                                              9.8
# 55-59                                             14.1
# 60-64                                              7.8
# 65 and over                                        6.7
# Not stated                                         1.3

# %% [markdown]
# # It didnt work. Transposed and dropped values in excel sheet and reentered the file below.

# %%
df1fatalbyageUPDATED = pd.read_csv("Fatal vehicle drivers by age by impairment UPDATED.csv")

# %%
data = {
    'Age': ['0-14', '15-20', '21-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65 and over', 'Not stated'],
    'HBD - under influence': [0, 37, 128, 158, 94, 62, 52, 43, 29, 41, 17, 19, 1],
    'HBD - not under influence': [0, 4, 10, 10, 16, 9, 5, 7, 2, 7, 3, 13, 0],
    'HBD - impairment unknown': [0, 6, 9, 11, 11, 13, 5, 5, 5, 6, 4, 7, 2]
}

# %%
plt.figure(figsize=(10, 8))

# Plot bars
plt.bar(df1fatalbyageUPDATED['Age'], df1fatalbyageUPDATED['HBD - under influence'], label='HBD - under influence', color='blue')
plt.bar(df1fatalbyageUPDATED['Age'], df1fatalbyageUPDATED['HBD - not under influence'], bottom=df1fatalbyageUPDATED['HBD - under influence'], label='HBD - not under influence', color='orange')
plt.bar(df1fatalbyageUPDATED['Age'], df1fatalbyageUPDATED['HBD - impairment unknown'], bottom=df1fatalbyageUPDATED['HBD - under influence']+df1fatalbyageUPDATED['HBD - not under influence'], label='HBD - impairment unknown', color='green')

# Customize legend
handles, labels = plt.gca().get_legend_handles_labels()
unique_labels = list(set(labels))
plt.legend(handles[:3], unique_labels, loc='upper right')

plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Counts of HBD by Age')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

plt.savefig('histogram.png')

# %%
df1alcINJURIES = pd.read_csv("ALCOHOL INVOLVED INJURY CRASHES BY DAY OF WEEK - 2019 - Copy.csv")

# %%
df1alcINJURIES
# Out:
#               Hour of Day  Monday  Tuesday  Wednesday  Thursday  Friday  \
# 0   Midnight - 12:59 A.M.     158      109        105       119     129
# 1        1:00 - 1:59 A.M.     145       87         96        97     134
# 2        2:00 - 2:59 A.M.     149       83         98       118     146
# 3        3:00 - 3:59 A.M.      74       53         50        65      82
# 4        4:00 - 4:59 A.M.      40       23         26        31      55
# 5        5:00 - 5:59 A.M.      22       20         24        22      49
# 6        6:00 - 6:59 A.M.      19       24         21        21      34
# 7        7:00 - 7:59 A.M.      33       39         29        29      40
# 8        8:00 - 8:59 A.M.      33       54         34        45      28
# 9        9:00 - 9:59 A.M.      26       20         17        22      32
# 10     10:00 - 10:59 A.M.      37       31         28        29      28
# 11     11:00 - 11:59 A.M.      37       24         37        33      34
# 12      Noon - 12:59 P.M.      38       51         48        52      51
# 13       1:00 - 1:59 P.M.      47       47         51        50      65
# 14       2:00 - 2:59 P.M.      75       71         73        57      65
# 15       3:00 - 3:59 P.M.     106       75         90        69     104
# 16       4:00 - 4:59 P.M.      98      103        116        99     122
# 17       5:00 - 5:59 P.M.     159      144        128        89     204
# 18       6:00 - 6:59 P.M.     117      138        151       155     196
# 19       7:00 - 7:59 P.M.     132      145        148       160     221
# 20       8:00 - 8:59 P.M.     130      147        166       166     224
# 21       9:00 - 9:59 P.M.     143      152        163       205     263
# 22     10:00 - 10:59 P.M.     131      142        150       193     280
# 23     11:00 - 11:59 P.M.     112      131        144       186     276
# 24           Unknown hour       5        7          2         6       4
#
#     Saturday  Sunday  Unnamed: 8
# 0        257     339         NaN
# 1        329     387         NaN
# 2        363     393         NaN
# 3        193     257         NaN
# 4        137     139         NaN
# 5         86      89         NaN
# 6         72      69         NaN
# 7         38      41         NaN
# 8         33      35         NaN
# 9         36      31         NaN
# 10        38      31         NaN
# 11        56      53         NaN
# 12        53      56         NaN
# 13        90      64         NaN
# 14        81     108         NaN
# 15       109     137         NaN
# 16       144     173         NaN
# 17       209     213         NaN
# 18       218     231         NaN
# 19       218     205         NaN
# 20       228     265         NaN
# 21       286     242         NaN
# 22       323     228         NaN
# 23       306     207         NaN
# 24         7      12         NaN

# %% [markdown]
# # Somehow my excel file got an added unnamed column. I removed it with the code below and then checked

# %%
df1alcINJURIES.drop(columns=['Unnamed: 8'], inplace=True)

# %%
df1alcINJURIES
# Out:
#               Hour of Day  Monday  Tuesday  Wednesday  Thursday  Friday  \
# 0   Midnight - 12:59 A.M.     158      109        105       119     129
# 1        1:00 - 1:59 A.M.     145       87         96        97     134
# 2        2:00 - 2:59 A.M.     149       83         98       118     146
# 3        3:00 - 3:59 A.M.      74       53         50        65      82
# 4        4:00 - 4:59 A.M.      40       23         26        31      55
# 5        5:00 - 5:59 A.M.      22       20         24        22      49
# 6        6:00 - 6:59 A.M.      19       24         21        21      34
# 7        7:00 - 7:59 A.M.      33       39         29        29      40
# 8        8:00 - 8:59 A.M.      33       54         34        45      28
# 9        9:00 - 9:59 A.M.      26       20         17        22      32
# 10     10:00 - 10:59 A.M.      37       31         28        29      28
# 11     11:00 - 11:59 A.M.      37       24         37        33      34
# 12      Noon - 12:59 P.M.      38       51         48        52      51
# 13       1:00 - 1:59 P.M.      47       47         51        50      65
# 14       2:00 - 2:59 P.M.      75       71         73        57      65
# 15       3:00 - 3:59 P.M.     106       75         90        69     104
# 16       4:00 - 4:59 P.M.      98      103        116        99     122
# 17       5:00 - 5:59 P.M.     159      144        128        89     204
# 18       6:00 - 6:59 P.M.     117      138        151       155     196
# 19       7:00 - 7:59 P.M.     132      145        148       160     221
# 20       8:00 - 8:59 P.M.     130      147        166       166     224
# 21       9:00 - 9:59 P.M.     143      152        163       205     263
# 22     10:00 - 10:59 P.M.     131      142        150       193     280
# 23     11:00 - 11:59 P.M.     112      131        144       186     276
# 24           Unknown hour       5        7          2         6       4
#
#     Saturday  Sunday
# 0        257     339
# 1        329     387
# 2        363     393
# 3        193     257
# 4        137     139
# 5         86      89
# 6         72      69
# 7         38      41
# 8         33      35
# 9         36      31
# 10        38      31
# 11        56      53
# 12        53      56
# 13        90      64
# 14        81     108
# 15       109     137
# 16       144     173
# 17       209     213
# 18       218     231
# 19       218     205
# 20       228     265
# 21       286     242
# 22       323     228
# 23       306     207
# 24         7      12

# %% [markdown]
# ## I want to drop the Unknown hour

# %%
df1alcINJURIES.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
df1alcINJURIES.drop('Unknown hour', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1alcINJURIES.drop('Unknown hour', inplace=True)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['Unknown hour'] not found in axis"

# %%
df1alcINJURIES

# %%
df1alcINJURIES.plot(kind='bar', figsize=(12, 8))
plt.xlabel('Hour of Day')
plt.ylabel('Counts')
plt.title('Counts by Hour of Day')
plt.xticks(rotation=90)
plt.legend(title='Day of Week')
plt.show()

# %%
df1alcINJURIES.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.xlabel('Time of day')
plt.ylabel('Counts')
plt.title('Counts by Day of Week and Hour of Day')
plt.xticks(rotation=90)
plt.legend(title='Day of Week')
plt.show()

# %%
dfAgeVictim = pd.read_csv("Alc crashes by Age and Victim 2019.csv")

# %%
dfAgeVictim
# Out:
#             Age  Driver Killed Driver Injured  Passenger Killed  \
# 0           0-4              0             14                 2
# 1             5              0              2                 1
# 2             6              0              2                 1
# 3             7              0              0                 1
# 4             8              0              0                 1
# 5             9              0              1                 3
# 6            10              0              3                 1
# 7            11              0              0                 1
# 8            12              0              1                 1
# 9            13              0              2                 3
# 10           14              0              2                 2
# 11           15              0             15                 6
# 12           16              1             39                 3
# 13           17              5            115                 6
# 14           18              3            263                 7
# 15           19              6            378                 5
# 16           20             12            429                 6
# 17           21             24            679                11
# 18           22             27            689                11
# 19           23             17            719                10
# 20           24             23            749                 6
# 21           25             37            711                 9
# 22           26             28            685                 5
# 23           27             18            659                 5
# 24           28             22            644                 8
# 25           29             22            586                 1
# 26           30             14            566                 4
# 27           31             16            497                 3
# 28           32             12            461                 3
# 29           33             19            446                 4
# 30           34             20            433                 2
# 31           35             13            408                 5
# 32           36             14            364                 2
# 33           37             12            369                 0
# 34           38             10            349                 5
# 35           39              6            333                 1
# 36           40             16            312                 2
# 37           41              7            282                 5
# 38           42              9            263                 3
# 39           43              7            267                 0
# 40           44             16            262                 1
# 41           45              8            228                 1
# 42           46              7            240                 0
# 43           47             10            256                 1
# 44           48              9            277                 1
# 45           49             13            261                 1
# 46           50              6            233                 2
# 47           51              7            223                 1
# 48           52              8            197                 4
# 49           53              7            199                 1
# 50           54              7            186                 1
# 51           55             10            193                 2
# 52           56              7            209                 1
# 53           57             12            191                 2
# 54           58             10            172                 0
# 55           59             12            167                 3
# 56  60 and over             65          1,620                20
# 57   Not stated              0             31                 5
# 58        Total            634         17,882               202
#
#    Passenger Injured  Pedestrian Killed Pedestrian Injured  Bicyclist Killed  \
# 0                243                  2                 15                 0
# 1                 79                  0                  4                 0
# 2                 84                  0                  1                 0
# 3                 89                  0                  1                 0
# 4                 72                  0                  2                 0
# 5                 84                  0                  2                 0
# 6                103                  1                  4                 0
# 7                113                  0                  5                 0
# 8                 87                  0                  4                 0
# 9                 96                  1                 11                 0
# 10                96                  1                 10                 0
# 11               131                  0                 20                 0
# 12               149                  1                 12                 0
# 13               168                  2                 19                 0
# 14               224                  0                 22                 0
# 15               228                  4                 22                 1
# 16               256                  3                 22                 0
# 17               280                  5                 30                 0
# 18               283                  8                 46                 1
# 19               238                  3                 37                 0
# 20               239                  4                 40                 1
# 21               221                  9                 42                 1
# 22               200                  7                 41                 0
# 23               208                  4                 45                 1
# 24               186                  6                 53                 1
# 25               165                  4                 37                 0
# 26               141                 13                 37                 3
# 27               107                 11                 38                 1
# 28               125                  5                 38                 1
# 29               110                  5                 32                 0
# 30                99                  5                 36                 1
# 31                91                  8                 39                 0
# 32                81                  4                 30                 2
# 33                92                  2                 21                 0
# 34                73                  4                 32                 0
# 35                93                  5                 26                 1
# 36                71                  5                 25                 0
# 37                60                  7                 23                 1
# 38                76                  4                 29                 1
# 39                80                 10                 18                 1
# 40                55                  1                 24                 2
# 41                68                  8                 25                 0
# 42                53                  6                 25                 0
# 43                63                  7                 28                 0
# 44                72                  4                 21                 0
# 45                75                  4                 26                 2
# 46                56                  4                 24                 0
# 47                59                  7                 25                 0
# 48                63                  8                 12                 1
# 49                38                  6                 18                 0
# 50                43                  8                 33                 0
# 51                70                  2                 30                 0
# 52                43                 11                 27                 2
# 53                45                  2                 29                 1
# 54                49                  4                 29                 0
# 55                40                  8                 26                 0
# 56               489                 70                224                 9
# 57               275                  3                 15                 0
# 58             7,277                316              1,612                35
#
#     Bicyclist Injured  Motorcyclist killed  Motorcyclist Injured Total Killed  \
# 0                   0                    0                     2            4
# 1                   0                    0                     0            1
# 2                   2                    0                     1            1
# 3                   1                    0                     2            1
# 4                   3                    0                     1            1
# 5                   0                    0                     2            3
# 6                   1                    1                     1            2
# 7                   1                    0                     1            1
# 8                   6                    0                     0            1
# 9                   2                    0                     0            4
# 10                  6                    0                     0            3
# 11                 10                    0                     2            6
# 12                  4                    0                     1            5
# 13                  8                    0                     3           13
# 14                  6                    0                     5           10
# 15                  9                    1                     8           16
# 16                  5                    2                     9           21
# 17                 10                    4                    20           40
# 18                 10                    6                    28           47
# 19                 14                    3                    15           30
# 20                 10                    4                    36           34
# 21                 14                   10                    25           56
# 22                  8                    7                    34           40
# 23                 24                    5                    33           28
# 24                 16                    6                    29           37
# 25                 11                    6                    31           27
# 26                 13                    2                    40           34
# 27                  8                    7                    32           31
# 28                  6                    5                    23           21
# 29                 12                    4                    23           28
# 30                  6                    3                    20           28
# 31                  8                    3                    23           26
# 32                 10                    5                    31           22
# 33                 12                    3                    22           14
# 34                 11                    5                    18           19
# 35                 13                    3                    15           13
# 36                 10                    2                    26           23
# 37                 16                    5                    22           20
# 38                  7                    1                    16           17
# 39                 10                    2                    22           18
# 40                  7                    2                     8           20
# 41                  7                    2                    11           17
# 42                  8                    2                    10           13
# 43                 11                    5                    13           18
# 44                  9                    4                    17           14
# 45                 16                    4                    15           20
# 46                 14                    1                    15           12
# 47                 11                    2                    10           15
# 48                 12                    2                    13           21
# 49                 11                    3                    14           14
# 50                 14                    3                     7           16
# 51                 14                    2                    11           14
# 52                  6                    2                    16           21
# 53                  7                    4                    19           17
# 54                 13                    4                    14           14
# 55                  9                    1                     8           23
# 56                 59                   15                    69          164
# 57                 11                    0                     6            8
# 58                562                  163                   898        1,187
#
#    Total Injured
# 0            272
# 1             85
# 2             89
# 3             91
# 4             77
# 5             87
# 6            111
# 7            119
# 8             98
# 9            111
# 10           114
# 11           176
# 12           204
# 13           310
# 14           515
# 15           637
# 16           712
# 17           999
# 18         1,028
# 19         1,008
# 20         1,038
# 21           988
# 22           934
# 23           936
# 24           899
# 25           799
# 26           757
# 27           650
# 28           630
# 29           600
# 30           574
# 31           546
# 32           485
# 33           494
# 34           465
# 35           465
# 36           418
# 37           381
# 38           375
# 39           375
# 40           348
# 41           328
# 42           326
# 43           358
# 44           379
# 45           378
# 46           327
# 47           318
# 48           284
# 49           266
# 50           276
# 51           307
# 52           285
# 53           272
# 54           263
# 55           242
# 56         2,392
# 57           332
# 58        27,333

# %%
dfAgeVictim.drop(columns=['Total Injured'], inplace=True)

# %%
dfAgeVictim.drop(columns=['Total Killed'], inplace=True)

# %%
dfAgeVictim.index
# Out:
# RangeIndex(start=0, stop=59, step=1)

# %%
dfAgeVictim.drop(58, inplace=True)

# %%
dfAgeVictim
# Out:
#             Age  Driver Killed Driver Injured  Passenger Killed  \
# 0           0-4              0             14                 2
# 1             5              0              2                 1
# 2             6              0              2                 1
# 3             7              0              0                 1
# 4             8              0              0                 1
# 5             9              0              1                 3
# 6            10              0              3                 1
# 7            11              0              0                 1
# 8            12              0              1                 1
# 9            13              0              2                 3
# 10           14              0              2                 2
# 11           15              0             15                 6
# 12           16              1             39                 3
# 13           17              5            115                 6
# 14           18              3            263                 7
# 15           19              6            378                 5
# 16           20             12            429                 6
# 17           21             24            679                11
# 18           22             27            689                11
# 19           23             17            719                10
# 20           24             23            749                 6
# 21           25             37            711                 9
# 22           26             28            685                 5
# 23           27             18            659                 5
# 24           28             22            644                 8
# 25           29             22            586                 1
# 26           30             14            566                 4
# 27           31             16            497                 3
# 28           32             12            461                 3
# 29           33             19            446                 4
# 30           34             20            433                 2
# 31           35             13            408                 5
# 32           36             14            364                 2
# 33           37             12            369                 0
# 34           38             10            349                 5
# 35           39              6            333                 1
# 36           40             16            312                 2
# 37           41              7            282                 5
# 38           42              9            263                 3
# 39           43              7            267                 0
# 40           44             16            262                 1
# 41           45              8            228                 1
# 42           46              7            240                 0
# 43           47             10            256                 1
# 44           48              9            277                 1
# 45           49             13            261                 1
# 46           50              6            233                 2
# 47           51              7            223                 1
# 48           52              8            197                 4
# 49           53              7            199                 1
# 50           54              7            186                 1
# 51           55             10            193                 2
# 52           56              7            209                 1
# 53           57             12            191                 2
# 54           58             10            172                 0
# 55           59             12            167                 3
# 56  60 and over             65          1,620                20
# 57   Not stated              0             31                 5
#
#    Passenger Injured  Pedestrian Killed Pedestrian Injured  Bicyclist Killed  \
# 0                243                  2                 15                 0
# 1                 79                  0                  4                 0
# 2                 84                  0                  1                 0
# 3                 89                  0                  1                 0
# 4                 72                  0                  2                 0
# 5                 84                  0                  2                 0
# 6                103                  1                  4                 0
# 7                113                  0                  5                 0
# 8                 87                  0                  4                 0
# 9                 96                  1                 11                 0
# 10                96                  1                 10                 0
# 11               131                  0                 20                 0
# 12               149                  1                 12                 0
# 13               168                  2                 19                 0
# 14               224                  0                 22                 0
# 15               228                  4                 22                 1
# 16               256                  3                 22                 0
# 17               280                  5                 30                 0
# 18               283                  8                 46                 1
# 19               238                  3                 37                 0
# 20               239                  4                 40                 1
# 21               221                  9                 42                 1
# 22               200                  7                 41                 0
# 23               208                  4                 45                 1
# 24               186                  6                 53                 1
# 25               165                  4                 37                 0
# 26               141                 13                 37                 3
# 27               107                 11                 38                 1
# 28               125                  5                 38                 1
# 29               110                  5                 32                 0
# 30                99                  5                 36                 1
# 31                91                  8                 39                 0
# 32                81                  4                 30                 2
# 33                92                  2                 21                 0
# 34                73                  4                 32                 0
# 35                93                  5                 26                 1
# 36                71                  5                 25                 0
# 37                60                  7                 23                 1
# 38                76                  4                 29                 1
# 39                80                 10                 18                 1
# 40                55                  1                 24                 2
# 41                68                  8                 25                 0
# 42                53                  6                 25                 0
# 43                63                  7                 28                 0
# 44                72                  4                 21                 0
# 45                75                  4                 26                 2
# 46                56                  4                 24                 0
# 47                59                  7                 25                 0
# 48                63                  8                 12                 1
# 49                38                  6                 18                 0
# 50                43                  8                 33                 0
# 51                70                  2                 30                 0
# 52                43                 11                 27                 2
# 53                45                  2                 29                 1
# 54                49                  4                 29                 0
# 55                40                  8                 26                 0
# 56               489                 70                224                 9
# 57               275                  3                 15                 0
#
#     Bicyclist Injured  Motorcyclist killed  Motorcyclist Injured
# 0                   0                    0                     2
# 1                   0                    0                     0
# 2                   2                    0                     1
# 3                   1                    0                     2
# 4                   3                    0                     1
# 5                   0                    0                     2
# 6                   1                    1                     1
# 7                   1                    0                     1
# 8                   6                    0                     0
# 9                   2                    0                     0
# 10                  6                    0                     0
# 11                 10                    0                     2
# 12                  4                    0                     1
# 13                  8                    0                     3
# 14                  6                    0                     5
# 15                  9                    1                     8
# 16                  5                    2                     9
# 17                 10                    4                    20
# 18                 10                    6                    28
# 19                 14                    3                    15
# 20                 10                    4                    36
# 21                 14                   10                    25
# 22                  8                    7                    34
# 23                 24                    5                    33
# 24                 16                    6                    29
# 25                 11                    6                    31
# 26                 13                    2                    40
# 27                  8                    7                    32
# 28                  6                    5                    23
# 29                 12                    4                    23
# 30                  6                    3                    20
# 31                  8                    3                    23
# 32                 10                    5                    31
# 33                 12                    3                    22
# 34                 11                    5                    18
# 35                 13                    3                    15
# 36                 10                    2                    26
# 37                 16                    5                    22
# 38                  7                    1                    16
# 39                 10                    2                    22
# 40                  7                    2                     8
# 41                  7                    2                    11
# 42                  8                    2                    10
# 43                 11                    5                    13
# 44                  9                    4                    17
# 45                 16                    4                    15
# 46                 14                    1                    15
# 47                 11                    2                    10
# 48                 12                    2                    13
# 49                 11                    3                    14
# 50                 14                    3                     7
# 51                 14                    2                    11
# 52                  6                    2                    16
# 53                  7                    4                    19
# 54                 13                    4                    14
# 55                  9                    1                     8
# 56                 59                   15                    69
# 57                 11                    0                     6

# %%
x = dfAgeVictim['Age']
y = dfAgeVictim['Driver Killed']

plt.figure(figsize=(10, 6))
plt.scatter(x, y)
plt.xlabel('Age')
plt.ylabel('Driver Killed')
plt.title('Scatter Plot of Driver Killed vs. Age')
plt.grid(True)
plt.show()

# %%
x = dfAgeVictim['Driver Injured']
y = dfAgeVictim['Age']

plt.figure(figsize=(10, 6))
plt.scatter(x, y)
plt.xlabel('Age')
plt.ylabel('Driver Injured')
plt.title('Scatter Plot of Driver Injured vs. Age')
plt.grid(True)
plt.show()

# %%
x = dfAgeVictim['Motorcyclist killed']
y = dfAgeVictim['Motorcyclist Injured']

plt.figure(figsize=(10, 6))
plt.scatter(x, y)
plt.xlabel('Motorcyclist killed')
plt.ylabel('Motorcyclist Injured')
plt.title('Scatter Plot of Motorcyclists Killed vs Injured')
plt.grid(True)
plt.show()

# %%
x = dfAgeVictim['Driver Injured']
y = dfAgeVictim['Passenger Injured']

plt.figure(figsize=(10, 6))
plt.scatter(x, y)
plt.xlabel('Motorcyclist killed')
plt.ylabel('Motorcyclist Injured')
plt.title('Scatter Plot of Motorcyclists Killed vs Injured')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(dfAgeVictim['Age'], bins=10, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages')
plt.grid(True)
plt.show()

# %%
print(dfAgeVictim.columns)

# If there are leading or trailing whitespaces, strip them
dfAgeVictim.columns = dfAgeVictim.columns.str.strip()

# Check again to see if it matches 'Age'
print(dfAgeVictim.columns)
# Out:
# Index(['Age', 'Driver Killed', 'Driver Injured', 'Passenger Killed',
#        'Passenger Injured', 'Pedestrian Killed', 'Pedestrian Injured',
#        'Bicyclist Killed', 'Bicyclist Injured', 'Motorcyclist killed',
#        'Motorcyclist Injured'],
#       dtype='object')
# Index(['Age', 'Driver Killed', 'Driver Injured', 'Passenger Killed',
#        'Passenger Injured', 'Pedestrian Killed', 'Pedestrian Injured',
#        'Bicyclist Killed', 'Bicyclist Injured', 'Motorcyclist killed',
#        'Motorcyclist Injured'],
#       dtype='object')

# %%
# Plot the bar chart
dfAgeVictim.plot(kind='bar', figsize=(15, 10))
plt.xlabel('Age')
plt.ylabel('Number of Individuals Killed')
plt.title('Comparison of Alcohol impaired Drivers Killed and Passengers Killed by Age')
plt.xticks(rotation=90)
plt.legend(title='Type of Individual', labels=['Drivers Killed', 'Passengers Killed'])
plt.show()

# %%
dfAgeVictim
# Out:
#             Age  Driver Killed Driver Injured  Passenger Killed  \
# 0           0-4              0             14                 2
# 1             5              0              2                 1
# 2             6              0              2                 1
# 3             7              0              0                 1
# 4             8              0              0                 1
# 5             9              0              1                 3
# 6            10              0              3                 1
# 7            11              0              0                 1
# 8            12              0              1                 1
# 9            13              0              2                 3
# 10           14              0              2                 2
# 11           15              0             15                 6
# 12           16              1             39                 3
# 13           17              5            115                 6
# 14           18              3            263                 7
# 15           19              6            378                 5
# 16           20             12            429                 6
# 17           21             24            679                11
# 18           22             27            689                11
# 19           23             17            719                10
# 20           24             23            749                 6
# 21           25             37            711                 9
# 22           26             28            685                 5
# 23           27             18            659                 5
# 24           28             22            644                 8
# 25           29             22            586                 1
# 26           30             14            566                 4
# 27           31             16            497                 3
# 28           32             12            461                 3
# 29           33             19            446                 4
# 30           34             20            433                 2
# 31           35             13            408                 5
# 32           36             14            364                 2
# 33           37             12            369                 0
# 34           38             10            349                 5
# 35           39              6            333                 1
# 36           40             16            312                 2
# 37           41              7            282                 5
# 38           42              9            263                 3
# 39           43              7            267                 0
# 40           44             16            262                 1
# 41           45              8            228                 1
# 42           46              7            240                 0
# 43           47             10            256                 1
# 44           48              9            277                 1
# 45           49             13            261                 1
# 46           50              6            233                 2
# 47           51              7            223                 1
# 48           52              8            197                 4
# 49           53              7            199                 1
# 50           54              7            186                 1
# 51           55             10            193                 2
# 52           56              7            209                 1
# 53           57             12            191                 2
# 54           58             10            172                 0
# 55           59             12            167                 3
# 56  60 and over             65          1,620                20
# 57   Not stated              0             31                 5
#
#    Passenger Injured  Pedestrian Killed Pedestrian Injured  Bicyclist Killed  \
# 0                243                  2                 15                 0
# 1                 79                  0                  4                 0
# 2                 84                  0                  1                 0
# 3                 89                  0                  1                 0
# 4                 72                  0                  2                 0
# 5                 84                  0                  2                 0
# 6                103                  1                  4                 0
# 7                113                  0                  5                 0
# 8                 87                  0                  4                 0
# 9                 96                  1                 11                 0
# 10                96                  1                 10                 0
# 11               131                  0                 20                 0
# 12               149                  1                 12                 0
# 13               168                  2                 19                 0
# 14               224                  0                 22                 0
# 15               228                  4                 22                 1
# 16               256                  3                 22                 0
# 17               280                  5                 30                 0
# 18               283                  8                 46                 1
# 19               238                  3                 37                 0
# 20               239                  4                 40                 1
# 21               221                  9                 42                 1
# 22               200                  7                 41                 0
# 23               208                  4                 45                 1
# 24               186                  6                 53                 1
# 25               165                  4                 37                 0
# 26               141                 13                 37                 3
# 27               107                 11                 38                 1
# 28               125                  5                 38                 1
# 29               110                  5                 32                 0
# 30                99                  5                 36                 1
# 31                91                  8                 39                 0
# 32                81                  4                 30                 2
# 33                92                  2                 21                 0
# 34                73                  4                 32                 0
# 35                93                  5                 26                 1
# 36                71                  5                 25                 0
# 37                60                  7                 23                 1
# 38                76                  4                 29                 1
# 39                80                 10                 18                 1
# 40                55                  1                 24                 2
# 41                68                  8                 25                 0
# 42                53                  6                 25                 0
# 43                63                  7                 28                 0
# 44                72                  4                 21                 0
# 45                75                  4                 26                 2
# 46                56                  4                 24                 0
# 47                59                  7                 25                 0
# 48                63                  8                 12                 1
# 49                38                  6                 18                 0
# 50                43                  8                 33                 0
# 51                70                  2                 30                 0
# 52                43                 11                 27                 2
# 53                45                  2                 29                 1
# 54                49                  4                 29                 0
# 55                40                  8                 26                 0
# 56               489                 70                224                 9
# 57               275                  3                 15                 0
#
#     Bicyclist Injured  Motorcyclist killed  Motorcyclist Injured
# 0                   0                    0                     2
# 1                   0                    0                     0
# 2                   2                    0                     1
# 3                   1                    0                     2
# 4                   3                    0                     1
# 5                   0                    0                     2
# 6                   1                    1                     1
# 7                   1                    0                     1
# 8                   6                    0                     0
# 9                   2                    0                     0
# 10                  6                    0                     0
# 11                 10                    0                     2
# 12                  4                    0                     1
# 13                  8                    0                     3
# 14                  6                    0                     5
# 15                  9                    1                     8
# 16                  5                    2                     9
# 17                 10                    4                    20
# 18                 10                    6                    28
# 19                 14                    3                    15
# 20                 10                    4                    36
# 21                 14                   10                    25
# 22                  8                    7                    34
# 23                 24                    5                    33
# 24                 16                    6                    29
# 25                 11                    6                    31
# 26                 13                    2                    40
# 27                  8                    7                    32
# 28                  6                    5                    23
# 29                 12                    4                    23
# 30                  6                    3                    20
# 31                  8                    3                    23
# 32                 10                    5                    31
# 33                 12                    3                    22
# 34                 11                    5                    18
# 35                 13                    3                    15
# 36                 10                    2                    26
# 37                 16                    5                    22
# 38                  7                    1                    16
# 39                 10                    2                    22
# 40                  7                    2                     8
# 41                  7                    2                    11
# 42                  8                    2                    10
# 43                 11                    5                    13
# 44                  9                    4                    17
# 45                 16                    4                    15
# 46                 14                    1                    15
# 47                 11                    2                    10
# 48                 12                    2                    13
# 49                 11                    3                    14
# 50                 14                    3                     7
# 51                 14                    2                    11
# 52                  6                    2                    16
# 53                  7                    4                    19
# 54                 13                    4                    14
# 55                  9                    1                     8
# 56                 59                   15                    69
# 57                 11                    0                     6

# %%
dftypeHBD = pd.read_csv("SWITRS 2019 Report.csv")

# %%
dftypeHBD
# Out:
#                                              HBD type 2015 Killed  \
# 0                                          HBD Driver         546
# 1                                      HBD Pedestrian         209
# 2                                       HBD Bicyclist          39
# 3                   Passenger in HBD Driver's Vehicle         186
# 4                                         HNBD Driver          79
# 5                                     HNBD Pedestrian          42
# 6                                      HNBD Bicyclist           9
# 7                  Passenger in HNBD Driver's Vehicle          34
# 8                                               Total       1,144
# 9            Percent HBD parties\nwere killed/injured        69.4
# 10  Percent passengers\nand HNBD parties\nwere kil...        30.6
#
#    2015 Injured 2016 Killed 2016 Injured 2017 Killed 2017 Injured 2018 Killed  \
# 0        11,054         545       11,976         587       11,874         533
# 1         1,040         248        1,128         249        1,059         265
# 2           532          29          500          29          446          25
# 3         3,423         173        3,613         174        3,468         136
# 4         4,948         103        5,666         113        5,582          93
# 5           494          63          515          62          535          78
# 6           203          11          171          14          169           9
# 7         3,458          51        3,825          66        3,834          82
# 8        25,152       1,223       27,394       1,294       26,967       1,221
# 9          50.2        67.2         49.7        66.8         49.6        67.4
# 10         49.8        32.8         50.3        33.2         50.4        32.6
#
#    2018 Injured 2019 Killed 2019 Injured
# 0        12,126         547       12,079
# 1         1,065         253        1,087
# 2           451          25          384
# 3         3,381         142        3,318
# 4         5,810          87        5,803
# 5           526          63          525
# 6           175          10          173
# 7         3,891          60        3,964
# 8        27,425       1,187       27,333
# 9          49.7        69.5         49.6
# 10         50.3        30.5         50.4

# %%
import matplotlib.pyplot as plt

# Extract the relevant data for HBD type, 2019 killed, and 2019 injured
hbd_type = ['HBD Driver', 'HBD Pedestrian', 'HBD Bicyclist', 
            'Passenger in HBD Driver\'s Vehicle', 'HNBD Driver', 
            'HNBD Pedestrian', 'HNBD Bicyclist', 
            'Passenger in HNBD Driver\'s Vehicle']
injured_2019 = [12079, 1087, 384, 3318, 5803, 525, 173, 3964]

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.barh(hbd_type, injured_2019, color='blue', label='2019 Injured', alpha=0.5)

# Add labels and title
plt.xlabel('Number of Cases')
plt.ylabel('HBD Type')
plt.title('Comparison of HBD Type with 2019 Killed and Injured')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract the relevant data for HBD type, 2019 killed, and 2019 injured
hbd_type = ['HBD Driver', 'HBD Pedestrian', 'HBD Bicyclist', 
            'Passenger in HBD Driver\'s Vehicle', 'HNBD Driver', 
            'HNBD Pedestrian', 'HNBD Bicyclist', 
            'Passenger in HNBD Driver\'s Vehicle']
injured_2019 = [12079, 1087, 384, 3318, 5803, 525, 173, 3964]

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.barh(hbd_type, killed_2019, color='maroon', label='2019 Killed', alpha=0.5)

# Add labels and title
plt.xlabel('Number of Cases')
plt.ylabel('HBD Type')
plt.title('Comparison of HBD Type with 2019 Killed and Injured')
plt.legend()

# Show the plot
plt.show()

# %%
dfFatalALCCounty = pd.read_csv("County Fatal Alc crashes.csv")

# %%
dfFatalALCCounty
# Out:
#              County  January  February  March  April   May  June  July  \
# 0           Alameda      4.0       3.0    3.0    2.0   3.0   1.0   3.0
# 1            Amador      NaN       NaN    NaN    NaN   1.0   NaN   2.0
# 2             Butte      NaN       1.0    NaN    NaN   NaN   NaN   NaN
# 3         Calaveras      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 4            Colusa      NaN       NaN    1.0    NaN   NaN   NaN   NaN
# 5      Contra Costa      2.0       4.0    2.0    2.0   1.0   4.0   2.0
# 6         Del Norte      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 7         El Dorado      1.0       3.0    NaN    1.0   NaN   1.0   2.0
# 8            Fresno      NaN       7.0    1.0    3.0   1.0   3.0   4.0
# 9             Glenn      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 10         Humboldt      1.0       1.0    NaN    NaN   1.0   3.0   1.0
# 11         Imperial      NaN       1.0    1.0    1.0   1.0   NaN   NaN
# 12             Kern      6.0       5.0    NaN    4.0   4.0   5.0   5.0
# 13            Kings      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 14             Lake      NaN       NaN    NaN    NaN   1.0   1.0   NaN
# 15      Los Angeles     15.0      19.0   17.0   19.0  13.0  20.0  16.0
# 16           Madera      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 17            Marin      1.0       NaN    1.0    2.0   1.0   NaN   1.0
# 18         Mariposa      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 19        Mendocino      1.0       NaN    1.0    1.0   NaN   NaN   2.0
# 20           Merced      NaN       NaN    4.0    NaN   2.0   2.0   NaN
# 21             Mono      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 22         Monterey      1.0       NaN    1.0    2.0   1.0   2.0   1.0
# 23             Napa      1.0       NaN    NaN    NaN   NaN   1.0   1.0
# 24           Nevada      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 25           Orange      9.0       5.0    6.0    4.0   3.0   9.0   4.0
# 26           Placer      1.0       NaN    1.0    NaN   NaN   NaN   NaN
# 27           Plumas      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 28        Riverside     11.0       3.0    6.0    7.0  10.0  13.0   9.0
# 29       Sacramento      4.0       NaN    4.0    6.0   3.0   8.0   4.0
# 30       San Benito      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 31   San Bernardino      5.0       6.0    3.0    4.0  15.0   8.0   9.0
# 32        San Diego      5.0       7.0   10.0    6.0   7.0   5.0   6.0
# 33    San Francisco      NaN       1.0    NaN    NaN   1.0   1.0   NaN
# 34      San Joaquin      4.0       2.0    4.0    2.0   2.0   1.0   2.0
# 35  San Luis Obispo      NaN       1.0    1.0    NaN   NaN   1.0   3.0
# 36        San Mateo      NaN       2.0    NaN    1.0   NaN   NaN   NaN
# 37    Santa Barbara      2.0       NaN    1.0    NaN   NaN   2.0   NaN
# 38      Santa Clara      3.0       NaN    2.0    3.0   3.0   5.0   3.0
# 39       Santa Cruz      NaN       2.0    2.0    NaN   NaN   NaN   NaN
# 40           Shasta      1.0       1.0    1.0    NaN   NaN   3.0   NaN
# 41         Siskiyou      NaN       NaN    NaN    NaN   NaN   NaN   1.0
# 42           Solano      1.0       NaN    2.0    1.0   1.0   NaN   1.0
# 43           Sonoma      NaN       1.0    2.0    NaN   1.0   1.0   1.0
# 44       Stanislaus      NaN       3.0    3.0    2.0   2.0   1.0   2.0
# 45           Sutter      NaN       NaN    NaN    NaN   2.0   NaN   NaN
# 46           Tehama      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 47          Trinity      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 48           Tulare      1.0       1.0    2.0    NaN   2.0   NaN   4.0
# 49         Tuolumne      1.0       NaN    NaN    NaN   1.0   NaN   NaN
# 50          Ventura      NaN       NaN    2.0    NaN   4.0   NaN   2.0
# 51             Yolo      1.0       NaN    1.0    1.0   2.0   NaN   NaN
# 52             Yuba      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 53             Inyo      NaN       NaN    NaN    NaN   NaN   NaN   1.0
#
#     August  September  October  November  December
# 0      4.0        2.0      2.0       NaN       1.0
# 1      1.0        NaN      NaN       NaN       NaN
# 2      3.0        1.0      2.0       1.0       1.0
# 3      1.0        1.0      1.0       1.0       NaN
# 4      NaN        NaN      NaN       NaN       NaN
# 5      1.0        5.0      1.0       1.0       2.0
# 6      NaN        NaN      NaN       NaN       1.0
# 7      NaN        1.0      1.0       1.0       NaN
# 8      5.0        2.0      1.0       2.0       5.0
# 9      NaN        NaN      1.0       NaN       NaN
# 10     1.0        4.0      1.0       NaN       1.0
# 11     NaN        2.0      NaN       1.0       NaN
# 12     5.0        1.0      5.0       3.0       5.0
# 13     2.0        1.0      1.0       NaN       1.0
# 14     NaN        NaN      NaN       1.0       2.0
# 15    16.0       10.0     20.0      23.0      14.0
# 16     NaN        2.0      2.0       1.0       1.0
# 17     NaN        1.0      NaN       NaN       NaN
# 18     NaN        1.0      NaN       NaN       1.0
# 19     NaN        2.0      NaN       1.0       1.0
# 20     1.0        1.0      2.0       1.0       NaN
# 21     NaN        NaN      1.0       NaN       NaN
# 22     NaN        2.0      1.0       1.0       2.0
# 23     1.0        1.0      NaN       NaN       NaN
# 24     NaN        NaN      1.0       NaN       NaN
# 25     4.0        2.0      6.0       3.0       6.0
# 26     2.0        NaN      1.0       1.0       1.0
# 27     NaN        1.0      NaN       NaN       NaN
# 28     6.0        8.0      7.0      12.0       9.0
# 29     4.0        5.0      1.0       3.0       6.0
# 30     NaN        NaN      1.0       NaN       NaN
# 31     8.0        6.0      8.0      14.0      10.0
# 32     5.0        4.0      7.0      11.0       7.0
# 33     NaN        NaN      1.0       NaN       NaN
# 34     4.0        4.0      1.0       3.0       2.0
# 35     NaN        NaN      3.0       1.0       1.0
# 36     NaN        1.0      NaN       1.0       NaN
# 37     NaN        3.0      NaN       NaN       1.0
# 38     3.0        4.0      2.0       4.0       2.0
# 39     NaN        2.0      1.0       NaN       NaN
# 40     1.0        3.0      1.0       1.0       NaN
# 41     NaN        NaN      NaN       NaN       NaN
# 42     1.0        2.0      1.0       2.0       NaN
# 43     2.0        NaN      1.0       1.0       1.0
# 44     2.0        2.0      NaN       2.0       4.0
# 45     1.0        NaN      2.0       NaN       1.0
# 46     1.0        1.0      2.0       1.0       1.0
# 47     NaN        2.0      NaN       NaN       NaN
# 48     2.0        2.0      1.0       2.0       2.0
# 49     NaN        1.0      1.0       NaN       1.0
# 50     2.0        1.0      1.0       NaN       1.0
# 51     NaN        NaN      1.0       1.0       1.0
# 52     NaN        NaN      1.0       1.0       NaN
# 53     NaN        NaN      NaN       NaN       NaN

# %%
# Example data (replace this with your actual data)
data = np.random.rand(10, 12)  # 10 counties, 12 months

# Plotting
plt.figure(figsize=(10, 6))
plt.imshow(data, cmap='viridis', aspect='auto')  # 'viridis' colormap is from light to dark
plt.colorbar(label='Number of occurrences')
plt.title('Heatmap of Monthly Data by County')
plt.xlabel('Month')
plt.ylabel('County')
plt.show()

# %%
import folium
import pandas as pd

# %%
from geopy.geocoders import Nominatim
import pandas as pd

# Initialize Nominatim geocoder
geolocator = Nominatim(user_agent="my_geocoder")

# Example list of counties (replace this with your actual data)
counties = ['Alameda', 'Amador', 'Butte', 'Calaveras', 'Colusa', 
'Contra Costa',
'Del Norte',
'El Dorado',
'Fresno',
'Glenn',
'Humbold',
'Imperial',
'Kern',
'Kings',
'Lake',
'Los Angeles',
'Madera',
'Marin',
'Mariposa',
'Mendocino',
'Merced',
'Mono',
'Monterey',
'Napa',
'Nevada',
'Orange',
'Placer',
'Plumas',
'Riverside',
'Sacramento',
'San Benito',
'San Bernardino',
'San Diego',
'San Francisco',
'San Joaquin',
'San Luis Obispo',
'San Mateo',
'Santa Barbara',
'Santa Clara',
'Santa Cruz',
'Shasta',
'Siskiyou',
'Solano',
'Sonoma',
'Stanislaus',
'Sutter',
'Tehama',
'Trinity',
'Tulare',
'Tuolumne',
'Ventura',
'Yolo',
'Yuba',
'Inyo']

# %%
latitudes = []
longitudes = []

# %%
for county in counties:
    location = geolocator.geocode(county + ", California")
    if location:
        latitudes.append(location.latitude)
        longitudes.append(location.longitude)
    else:
        latitudes.append(None)
        longitudes.append(None)

# Create a DataFrame with the county names and their coordinates
county_data = pd.DataFrame({'County': counties, 'Latitude': latitudes, 'Longitude': longitudes})

# Display the DataFrame
print(county_data)
# Out:
#              County   Latitude   Longitude
# 0           Alameda  37.609029 -121.899142
# 1            Amador  38.449089 -120.591102
# 2             Butte  39.651927 -121.585844
# 3         Calaveras  38.255818 -120.498149
# 4            Colusa  39.146558 -122.220956
# 5      Contra Costa  37.903481 -121.917535
# 6         Del Norte  41.726177 -123.913280
# 7         El Dorado  38.757414 -120.527613
# 8            Fresno  36.729529 -119.708861
# 9             Glenn  39.591277 -122.377866
# 10          Humbold  40.801551 -124.169394
# 11         Imperial  33.030549 -115.359567
# 12             Kern  35.314570 -118.753822
# 13            Kings  36.078481 -119.795634
# 14             Lake  39.050541 -122.777656
# 15      Los Angeles  34.053691 -118.242766
# 16           Madera  37.171626 -119.773799
# 17            Marin  38.040914 -122.619964
# 18         Mariposa  37.570148 -119.903659
# 19        Mendocino  39.317649 -123.412640
# 20           Merced  37.164154 -120.767860
# 21             Mono  37.953393 -118.939876
# 22         Monterey  36.223108 -121.387742
# 23             Napa  38.297137 -122.285529
# 24           Nevada  39.354033 -120.808984
# 25           Orange  33.750631 -117.872231
# 26           Placer  39.101206 -120.765061
# 27           Plumas  39.943099 -120.805952
# 28        Riverside  33.721999 -116.037247
# 29       Sacramento  38.581061 -121.493895
# 30       San Benito  36.624809 -121.117738
# 31   San Bernardino  34.825302 -116.083314
# 32        San Diego  32.717420 -117.162772
# 33    San Francisco  37.779026 -122.419906
# 34      San Joaquin  37.937290 -121.277372
# 35  San Luis Obispo  35.354021 -120.375716
# 36        San Mateo  37.496904 -122.333057
# 37    Santa Barbara  34.422132 -119.702667
# 38      Santa Clara  37.233325 -121.684635
# 39       Santa Cruz  37.050096 -121.990590
# 40           Shasta  40.796512 -121.997919
# 41         Siskiyou  41.686247 -122.536012
# 42           Solano  38.221894 -121.916355
# 43           Sonoma  38.511080 -122.847339
# 44       Stanislaus  37.550087 -121.050143
# 45           Sutter  38.950967 -121.697088
# 46           Tehama  40.125133 -122.201553
# 47          Trinity  40.605326 -123.171268
# 48           Tulare  36.251647 -118.852583
# 49         Tuolumne  38.056944 -119.991935
# 50          Ventura  34.445825 -119.077936
# 51             Yolo  38.718454 -121.905900
# 52             Yuba  39.283975 -121.355682
# 53             Inyo  36.559533 -117.407471

# %%
merged_data = pd.merge(dfFatalALCCounty, county_data, on='County', how='left')

# Display the merged dataset
print(merged_data)
# Out:
#              County  January  February  March  April   May  June  July  \
# 0           Alameda      4.0       3.0    3.0    2.0   3.0   1.0   3.0
# 1            Amador      NaN       NaN    NaN    NaN   1.0   NaN   2.0
# 2             Butte      NaN       1.0    NaN    NaN   NaN   NaN   NaN
# 3         Calaveras      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 4            Colusa      NaN       NaN    1.0    NaN   NaN   NaN   NaN
# 5      Contra Costa      2.0       4.0    2.0    2.0   1.0   4.0   2.0
# 6         Del Norte      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 7         El Dorado      1.0       3.0    NaN    1.0   NaN   1.0   2.0
# 8            Fresno      NaN       7.0    1.0    3.0   1.0   3.0   4.0
# 9             Glenn      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 10         Humboldt      1.0       1.0    NaN    NaN   1.0   3.0   1.0
# 11         Imperial      NaN       1.0    1.0    1.0   1.0   NaN   NaN
# 12             Kern      6.0       5.0    NaN    4.0   4.0   5.0   5.0
# 13            Kings      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 14             Lake      NaN       NaN    NaN    NaN   1.0   1.0   NaN
# 15      Los Angeles     15.0      19.0   17.0   19.0  13.0  20.0  16.0
# 16           Madera      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 17            Marin      1.0       NaN    1.0    2.0   1.0   NaN   1.0
# 18         Mariposa      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 19        Mendocino      1.0       NaN    1.0    1.0   NaN   NaN   2.0
# 20           Merced      NaN       NaN    4.0    NaN   2.0   2.0   NaN
# 21             Mono      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 22         Monterey      1.0       NaN    1.0    2.0   1.0   2.0   1.0
# 23             Napa      1.0       NaN    NaN    NaN   NaN   1.0   1.0
# 24           Nevada      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 25           Orange      9.0       5.0    6.0    4.0   3.0   9.0   4.0
# 26           Placer      1.0       NaN    1.0    NaN   NaN   NaN   NaN
# 27           Plumas      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 28        Riverside     11.0       3.0    6.0    7.0  10.0  13.0   9.0
# 29       Sacramento      4.0       NaN    4.0    6.0   3.0   8.0   4.0
# 30       San Benito      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 31   San Bernardino      5.0       6.0    3.0    4.0  15.0   8.0   9.0
# 32        San Diego      5.0       7.0   10.0    6.0   7.0   5.0   6.0
# 33    San Francisco      NaN       1.0    NaN    NaN   1.0   1.0   NaN
# 34      San Joaquin      4.0       2.0    4.0    2.0   2.0   1.0   2.0
# 35  San Luis Obispo      NaN       1.0    1.0    NaN   NaN   1.0   3.0
# 36        San Mateo      NaN       2.0    NaN    1.0   NaN   NaN   NaN
# 37    Santa Barbara      2.0       NaN    1.0    NaN   NaN   2.0   NaN
# 38      Santa Clara      3.0       NaN    2.0    3.0   3.0   5.0   3.0
# 39       Santa Cruz      NaN       2.0    2.0    NaN   NaN   NaN   NaN
# 40           Shasta      1.0       1.0    1.0    NaN   NaN   3.0   NaN
# 41         Siskiyou      NaN       NaN    NaN    NaN   NaN   NaN   1.0
# 42           Solano      1.0       NaN    2.0    1.0   1.0   NaN   1.0
# 43           Sonoma      NaN       1.0    2.0    NaN   1.0   1.0   1.0
# 44       Stanislaus      NaN       3.0    3.0    2.0   2.0   1.0   2.0
# 45           Sutter      NaN       NaN    NaN    NaN   2.0   NaN   NaN
# 46           Tehama      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 47          Trinity      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 48           Tulare      1.0       1.0    2.0    NaN   2.0   NaN   4.0
# 49         Tuolumne      1.0       NaN    NaN    NaN   1.0   NaN   NaN
# 50          Ventura      NaN       NaN    2.0    NaN   4.0   NaN   2.0
# 51             Yolo      1.0       NaN    1.0    1.0   2.0   NaN   NaN
# 52             Yuba      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 53             Inyo      NaN       NaN    NaN    NaN   NaN   NaN   1.0
#
#     August  September  October  November  December   Latitude   Longitude
# 0      4.0        2.0      2.0       NaN       1.0  37.609029 -121.899142
# 1      1.0        NaN      NaN       NaN       NaN  38.449089 -120.591102
# 2      3.0        1.0      2.0       1.0       1.0  39.651927 -121.585844
# 3      1.0        1.0      1.0       1.0       NaN  38.255818 -120.498149
# 4      NaN        NaN      NaN       NaN       NaN  39.146558 -122.220956
# 5      1.0        5.0      1.0       1.0       2.0  37.903481 -121.917535
# 6      NaN        NaN      NaN       NaN       1.0  41.726177 -123.913280
# 7      NaN        1.0      1.0       1.0       NaN  38.757414 -120.527613
# 8      5.0        2.0      1.0       2.0       5.0  36.729529 -119.708861
# 9      NaN        NaN      1.0       NaN       NaN  39.591277 -122.377866
# 10     1.0        4.0      1.0       NaN       1.0        NaN         NaN
# 11     NaN        2.0      NaN       1.0       NaN  33.030549 -115.359567
# 12     5.0        1.0      5.0       3.0       5.0  35.314570 -118.753822
# 13     2.0        1.0      1.0       NaN       1.0  36.078481 -119.795634
# 14     NaN        NaN      NaN       1.0       2.0  39.050541 -122.777656
# 15    16.0       10.0     20.0      23.0      14.0  34.053691 -118.242766
# 16     NaN        2.0      2.0       1.0       1.0  37.171626 -119.773799
# 17     NaN        1.0      NaN       NaN       NaN  38.040914 -122.619964
# 18     NaN        1.0      NaN       NaN       1.0  37.570148 -119.903659
# 19     NaN        2.0      NaN       1.0       1.0  39.317649 -123.412640
# 20     1.0        1.0      2.0       1.0       NaN  37.164154 -120.767860
# 21     NaN        NaN      1.0       NaN       NaN  37.953393 -118.939876
# 22     NaN        2.0      1.0       1.0       2.0  36.223108 -121.387742
# 23     1.0        1.0      NaN       NaN       NaN  38.297137 -122.285529
# 24     NaN        NaN      1.0       NaN       NaN  39.354033 -120.808984
# 25     4.0        2.0      6.0       3.0       6.0  33.750631 -117.872231
# 26     2.0        NaN      1.0       1.0       1.0  39.101206 -120.765061
# 27     NaN        1.0      NaN       NaN       NaN  39.943099 -120.805952
# 28     6.0        8.0      7.0      12.0       9.0  33.721999 -116.037247
# 29     4.0        5.0      1.0       3.0       6.0  38.581061 -121.493895
# 30     NaN        NaN      1.0       NaN       NaN  36.624809 -121.117738
# 31     8.0        6.0      8.0      14.0      10.0  34.825302 -116.083314
# 32     5.0        4.0      7.0      11.0       7.0  32.717420 -117.162772
# 33     NaN        NaN      1.0       NaN       NaN  37.779026 -122.419906
# 34     4.0        4.0      1.0       3.0       2.0  37.937290 -121.277372
# 35     NaN        NaN      3.0       1.0       1.0  35.354021 -120.375716
# 36     NaN        1.0      NaN       1.0       NaN  37.496904 -122.333057
# 37     NaN        3.0      NaN       NaN       1.0  34.422132 -119.702667
# 38     3.0        4.0      2.0       4.0       2.0  37.233325 -121.684635
# 39     NaN        2.0      1.0       NaN       NaN  37.050096 -121.990590
# 40     1.0        3.0      1.0       1.0       NaN  40.796512 -121.997919
# 41     NaN        NaN      NaN       NaN       NaN  41.686247 -122.536012
# 42     1.0        2.0      1.0       2.0       NaN  38.221894 -121.916355
# 43     2.0        NaN      1.0       1.0       1.0  38.511080 -122.847339
# 44     2.0        2.0      NaN       2.0       4.0  37.550087 -121.050143
# 45     1.0        NaN      2.0       NaN       1.0  38.950967 -121.697088
# 46     1.0        1.0      2.0       1.0       1.0  40.125133 -122.201553
# 47     NaN        2.0      NaN       NaN       NaN  40.605326 -123.171268
# 48     2.0        2.0      1.0       2.0       2.0  36.251647 -118.852583
# 49     NaN        1.0      1.0       NaN       1.0  38.056944 -119.991935
# 50     2.0        1.0      1.0       NaN       1.0  34.445825 -119.077936
# 51     NaN        NaN      1.0       1.0       1.0  38.718454 -121.905900
# 52     NaN        NaN      1.0       1.0       NaN  39.283975 -121.355682
# 53     NaN        NaN      NaN       NaN       NaN  36.559533 -117.407471

# %%
gfd3 = gpd.GeoDataFrame(merged_data, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(merged_data.Latitude, merged_data.Longitude))

# %%
gfd3
# Out:
#              County  January  February  March  April   May  June  July  \
# 0           Alameda      4.0       3.0    3.0    2.0   3.0   1.0   3.0
# 1            Amador      NaN       NaN    NaN    NaN   1.0   NaN   2.0
# 2             Butte      NaN       1.0    NaN    NaN   NaN   NaN   NaN
# 3         Calaveras      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 4            Colusa      NaN       NaN    1.0    NaN   NaN   NaN   NaN
# 5      Contra Costa      2.0       4.0    2.0    2.0   1.0   4.0   2.0
# 6         Del Norte      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 7         El Dorado      1.0       3.0    NaN    1.0   NaN   1.0   2.0
# 8            Fresno      NaN       7.0    1.0    3.0   1.0   3.0   4.0
# 9             Glenn      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 10         Humboldt      1.0       1.0    NaN    NaN   1.0   3.0   1.0
# 11         Imperial      NaN       1.0    1.0    1.0   1.0   NaN   NaN
# 12             Kern      6.0       5.0    NaN    4.0   4.0   5.0   5.0
# 13            Kings      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 14             Lake      NaN       NaN    NaN    NaN   1.0   1.0   NaN
# 15      Los Angeles     15.0      19.0   17.0   19.0  13.0  20.0  16.0
# 16           Madera      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 17            Marin      1.0       NaN    1.0    2.0   1.0   NaN   1.0
# 18         Mariposa      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 19        Mendocino      1.0       NaN    1.0    1.0   NaN   NaN   2.0
# 20           Merced      NaN       NaN    4.0    NaN   2.0   2.0   NaN
# 21             Mono      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 22         Monterey      1.0       NaN    1.0    2.0   1.0   2.0   1.0
# 23             Napa      1.0       NaN    NaN    NaN   NaN   1.0   1.0
# 24           Nevada      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 25           Orange      9.0       5.0    6.0    4.0   3.0   9.0   4.0
# 26           Placer      1.0       NaN    1.0    NaN   NaN   NaN   NaN
# 27           Plumas      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 28        Riverside     11.0       3.0    6.0    7.0  10.0  13.0   9.0
# 29       Sacramento      4.0       NaN    4.0    6.0   3.0   8.0   4.0
# 30       San Benito      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 31   San Bernardino      5.0       6.0    3.0    4.0  15.0   8.0   9.0
# 32        San Diego      5.0       7.0   10.0    6.0   7.0   5.0   6.0
# 33    San Francisco      NaN       1.0    NaN    NaN   1.0   1.0   NaN
# 34      San Joaquin      4.0       2.0    4.0    2.0   2.0   1.0   2.0
# 35  San Luis Obispo      NaN       1.0    1.0    NaN   NaN   1.0   3.0
# 36        San Mateo      NaN       2.0    NaN    1.0   NaN   NaN   NaN
# 37    Santa Barbara      2.0       NaN    1.0    NaN   NaN   2.0   NaN
# 38      Santa Clara      3.0       NaN    2.0    3.0   3.0   5.0   3.0
# 39       Santa Cruz      NaN       2.0    2.0    NaN   NaN   NaN   NaN
# 40           Shasta      1.0       1.0    1.0    NaN   NaN   3.0   NaN
# 41         Siskiyou      NaN       NaN    NaN    NaN   NaN   NaN   1.0
# 42           Solano      1.0       NaN    2.0    1.0   1.0   NaN   1.0
# 43           Sonoma      NaN       1.0    2.0    NaN   1.0   1.0   1.0
# 44       Stanislaus      NaN       3.0    3.0    2.0   2.0   1.0   2.0
# 45           Sutter      NaN       NaN    NaN    NaN   2.0   NaN   NaN
# 46           Tehama      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 47          Trinity      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 48           Tulare      1.0       1.0    2.0    NaN   2.0   NaN   4.0
# 49         Tuolumne      1.0       NaN    NaN    NaN   1.0   NaN   NaN
# 50          Ventura      NaN       NaN    2.0    NaN   4.0   NaN   2.0
# 51             Yolo      1.0       NaN    1.0    1.0   2.0   NaN   NaN
# 52             Yuba      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 53             Inyo      NaN       NaN    NaN    NaN   NaN   NaN   1.0
#
#     August  September  October  November  December   Latitude   Longitude  \
# 0      4.0        2.0      2.0       NaN       1.0  37.609029 -121.899142
# 1      1.0        NaN      NaN       NaN       NaN  38.449089 -120.591102
# 2      3.0        1.0      2.0       1.0       1.0  39.651927 -121.585844
# 3      1.0        1.0      1.0       1.0       NaN  38.255818 -120.498149
# 4      NaN        NaN      NaN       NaN       NaN  39.146558 -122.220956
# 5      1.0        5.0      1.0       1.0       2.0  37.903481 -121.917535
# 6      NaN        NaN      NaN       NaN       1.0  41.726177 -123.913280
# 7      NaN        1.0      1.0       1.0       NaN  38.757414 -120.527613
# 8      5.0        2.0      1.0       2.0       5.0  36.729529 -119.708861
# 9      NaN        NaN      1.0       NaN       NaN  39.591277 -122.377866
# 10     1.0        4.0      1.0       NaN       1.0        NaN         NaN
# 11     NaN        2.0      NaN       1.0       NaN  33.030549 -115.359567
# 12     5.0        1.0      5.0       3.0       5.0  35.314570 -118.753822
# 13     2.0        1.0      1.0       NaN       1.0  36.078481 -119.795634
# 14     NaN        NaN      NaN       1.0       2.0  39.050541 -122.777656
# 15    16.0       10.0     20.0      23.0      14.0  34.053691 -118.242766
# 16     NaN        2.0      2.0       1.0       1.0  37.171626 -119.773799
# 17     NaN        1.0      NaN       NaN       NaN  38.040914 -122.619964
# 18     NaN        1.0      NaN       NaN       1.0  37.570148 -119.903659
# 19     NaN        2.0      NaN       1.0       1.0  39.317649 -123.412640
# 20     1.0        1.0      2.0       1.0       NaN  37.164154 -120.767860
# 21     NaN        NaN      1.0       NaN       NaN  37.953393 -118.939876
# 22     NaN        2.0      1.0       1.0       2.0  36.223108 -121.387742
# 23     1.0        1.0      NaN       NaN       NaN  38.297137 -122.285529
# 24     NaN        NaN      1.0       NaN       NaN  39.354033 -120.808984
# 25     4.0        2.0      6.0       3.0       6.0  33.750631 -117.872231
# 26     2.0        NaN      1.0       1.0       1.0  39.101206 -120.765061
# 27     NaN        1.0      NaN       NaN       NaN  39.943099 -120.805952
# 28     6.0        8.0      7.0      12.0       9.0  33.721999 -116.037247
# 29     4.0        5.0      1.0       3.0       6.0  38.581061 -121.493895
# 30     NaN        NaN      1.0       NaN       NaN  36.624809 -121.117738
# 31     8.0        6.0      8.0      14.0      10.0  34.825302 -116.083314
# 32     5.0        4.0      7.0      11.0       7.0  32.717420 -117.162772
# 33     NaN        NaN      1.0       NaN       NaN  37.779026 -122.419906
# 34     4.0        4.0      1.0       3.0       2.0  37.937290 -121.277372
# 35     NaN        NaN      3.0       1.0       1.0  35.354021 -120.375716
# 36     NaN        1.0      NaN       1.0       NaN  37.496904 -122.333057
# 37     NaN        3.0      NaN       NaN       1.0  34.422132 -119.702667
# 38     3.0        4.0      2.0       4.0       2.0  37.233325 -121.684635
# 39     NaN        2.0      1.0       NaN       NaN  37.050096 -121.990590
# 40     1.0        3.0      1.0       1.0       NaN  40.796512 -121.997919
# 41     NaN        NaN      NaN       NaN       NaN  41.686247 -122.536012
# 42     1.0        2.0      1.0       2.0       NaN  38.221894 -121.916355
# 43     2.0        NaN      1.0       1.0       1.0  38.511080 -122.847339
# 44     2.0        2.0      NaN       2.0       4.0  37.550087 -121.050143
# 45     1.0        NaN      2.0       NaN       1.0  38.950967 -121.697088
# 46     1.0        1.0      2.0       1.0       1.0  40.125133 -122.201553
# 47     NaN        2.0      NaN       NaN       NaN  40.605326 -123.171268
# 48     2.0        2.0      1.0       2.0       2.0  36.251647 -118.852583
# 49     NaN        1.0      1.0       NaN       1.0  38.056944 -119.991935
# 50     2.0        1.0      1.0       NaN       1.0  34.445825 -119.077936
# 51     NaN        NaN      1.0       1.0       1.0  38.718454 -121.905900
# 52     NaN        NaN      1.0       1.0       NaN  39.283975 -121.355682
# 53     NaN        NaN      NaN       NaN       NaN  36.559533 -117.407471
#
#                        geometry
# 0   POINT (37.60903 -121.89914)
# 1   POINT (38.44909 -120.59110)
# 2   POINT (39.65193 -121.58584)
# 3   POINT (38.25582 -120.49815)
# 4   POINT (39.14656 -122.22096)
# 5   POINT (37.90348 -121.91753)
# 6   POINT (41.72618 -123.91328)
# 7   POINT (38.75741 -120.52761)
# 8   POINT (36.72953 -119.70886)
# 9   POINT (39.59128 -122.37787)
# 10                  POINT EMPTY
# 11  POINT (33.03055 -115.35957)
# 12  POINT (35.31457 -118.75382)
# 13  POINT (36.07848 -119.79563)
# 14  POINT (39.05054 -122.77766)
# 15  POINT (34.05369 -118.24277)
# 16  POINT (37.17163 -119.77380)
# 17  POINT (38.04091 -122.61996)
# 18  POINT (37.57015 -119.90366)
# 19  POINT (39.31765 -123.41264)
# 20  POINT (37.16415 -120.76786)
# 21  POINT (37.95339 -118.93988)
# 22  POINT (36.22311 -121.38774)
# 23  POINT (38.29714 -122.28553)
# 24  POINT (39.35403 -120.80898)
# 25  POINT (33.75063 -117.87223)
# 26  POINT (39.10121 -120.76506)
# 27  POINT (39.94310 -120.80595)
# 28  POINT (33.72200 -116.03725)
# 29  POINT (38.58106 -121.49389)
# 30  POINT (36.62481 -121.11774)
# 31  POINT (34.82530 -116.08331)
# 32  POINT (32.71742 -117.16277)
# 33  POINT (37.77903 -122.41991)
# 34  POINT (37.93729 -121.27737)
# 35  POINT (35.35402 -120.37572)
# 36  POINT (37.49690 -122.33306)
# 37  POINT (34.42213 -119.70267)
# 38  POINT (37.23333 -121.68463)
# 39  POINT (37.05010 -121.99059)
# 40  POINT (40.79651 -121.99792)
# 41  POINT (41.68625 -122.53601)
# 42  POINT (38.22189 -121.91636)
# 43  POINT (38.51108 -122.84734)
# 44  POINT (37.55009 -121.05014)
# 45  POINT (38.95097 -121.69709)
# 46  POINT (40.12513 -122.20155)
# 47  POINT (40.60533 -123.17127)
# 48  POINT (36.25165 -118.85258)
# 49  POINT (38.05694 -119.99194)
# 50  POINT (34.44582 -119.07794)
# 51  POINT (38.71845 -121.90590)
# 52  POINT (39.28398 -121.35568)
# 53  POINT (36.55953 -117.40747)

# %%
gfd3.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import folium
import pandas as pd

california_map = folium.Map(location=[36.7783, -119.4179], zoom_start=6)

# Loop through each row in the merged dataset
for index, row in merged_data.iterrows():
    county = row['County']
    latitude = row['Latitude']
    longitude = row['Longitude']
    value = row['January']  
    # If the latitude or longitude is NaN, skip this row
    if pd.isnull(latitude) or pd.isnull(longitude):
        continue
    
    # Color code the counties based on the column values
    if value < 3:
        color = 'green'
    elif 3 <= value < 6:
        color = 'orange'
    else:
        color = 'red'
    
    # Add a marker for each county with a popup showing the county name and value
    folium.CircleMarker(
        location=[latitude, longitude],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"{county}: {value}"
    ).add_to(california_map)

# Save the map
california_map.save('county_map.html')

# %% [markdown]
# ## This is just for january. I want to see the total across all months
# ### So I imported same csv file with the total included and mapped that out using the same code

# %%
dfFatalALCCountyTotal = pd.read_csv("County Fatal Alc crashes with total.csv")

# %%
dfFatalALCCountyTotal
# Out:
#              County  January  February  March  April   May  June  July  \
# 0           Alameda      4.0       3.0    3.0    2.0   3.0   1.0   3.0
# 1            Amador      NaN       NaN    NaN    NaN   1.0   NaN   2.0
# 2             Butte      NaN       1.0    NaN    NaN   NaN   NaN   NaN
# 3         Calaveras      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 4            Colusa      NaN       NaN    1.0    NaN   NaN   NaN   NaN
# 5      Contra Costa      2.0       4.0    2.0    2.0   1.0   4.0   2.0
# 6         Del Norte      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 7         El Dorado      1.0       3.0    NaN    1.0   NaN   1.0   2.0
# 8            Fresno      NaN       7.0    1.0    3.0   1.0   3.0   4.0
# 9             Glenn      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 10         Humboldt      1.0       1.0    NaN    NaN   1.0   3.0   1.0
# 11         Imperial      NaN       1.0    1.0    1.0   1.0   NaN   NaN
# 12             Kern      6.0       5.0    NaN    4.0   4.0   5.0   5.0
# 13            Kings      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 14             Lake      NaN       NaN    NaN    NaN   1.0   1.0   NaN
# 15      Los Angeles     15.0      19.0   17.0   19.0  13.0  20.0  16.0
# 16           Madera      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 17            Marin      1.0       NaN    1.0    2.0   1.0   NaN   1.0
# 18         Mariposa      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 19        Mendocino      1.0       NaN    1.0    1.0   NaN   NaN   2.0
# 20           Merced      NaN       NaN    4.0    NaN   2.0   2.0   NaN
# 21             Mono      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 22         Monterey      1.0       NaN    1.0    2.0   1.0   2.0   1.0
# 23             Napa      1.0       NaN    NaN    NaN   NaN   1.0   1.0
# 24           Nevada      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 25           Orange      9.0       5.0    6.0    4.0   3.0   9.0   4.0
# 26           Placer      1.0       NaN    1.0    NaN   NaN   NaN   NaN
# 27           Plumas      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 28        Riverside     11.0       3.0    6.0    7.0  10.0  13.0   9.0
# 29       Sacramento      4.0       NaN    4.0    6.0   3.0   8.0   4.0
# 30       San Benito      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 31   San Bernardino      5.0       6.0    3.0    4.0  15.0   8.0   9.0
# 32        San Diego      5.0       7.0   10.0    6.0   7.0   5.0   6.0
# 33    San Francisco      NaN       1.0    NaN    NaN   1.0   1.0   NaN
# 34      San Joaquin      4.0       2.0    4.0    2.0   2.0   1.0   2.0
# 35  San Luis Obispo      NaN       1.0    1.0    NaN   NaN   1.0   3.0
# 36        San Mateo      NaN       2.0    NaN    1.0   NaN   NaN   NaN
# 37    Santa Barbara      2.0       NaN    1.0    NaN   NaN   2.0   NaN
# 38      Santa Clara      3.0       NaN    2.0    3.0   3.0   5.0   3.0
# 39       Santa Cruz      NaN       2.0    2.0    NaN   NaN   NaN   NaN
# 40           Shasta      1.0       1.0    1.0    NaN   NaN   3.0   NaN
# 41         Siskiyou      NaN       NaN    NaN    NaN   NaN   NaN   1.0
# 42           Solano      1.0       NaN    2.0    1.0   1.0   NaN   1.0
# 43           Sonoma      NaN       1.0    2.0    NaN   1.0   1.0   1.0
# 44       Stanislaus      NaN       3.0    3.0    2.0   2.0   1.0   2.0
# 45           Sutter      NaN       NaN    NaN    NaN   2.0   NaN   NaN
# 46           Tehama      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 47          Trinity      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 48           Tulare      1.0       1.0    2.0    NaN   2.0   NaN   4.0
# 49         Tuolumne      1.0       NaN    NaN    NaN   1.0   NaN   NaN
# 50          Ventura      NaN       NaN    2.0    NaN   4.0   NaN   2.0
# 51             Yolo      1.0       NaN    1.0    1.0   2.0   NaN   NaN
# 52             Yuba      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 53             Inyo      NaN       NaN    NaN    NaN   NaN   NaN   1.0
#
#     August  September  October  November  December  Total
# 0      4.0        2.0      2.0       NaN       1.0     28
# 1      1.0        NaN      NaN       NaN       NaN      4
# 2      3.0        1.0      2.0       1.0       1.0      9
# 3      1.0        1.0      1.0       1.0       NaN      4
# 4      NaN        NaN      NaN       NaN       NaN      1
# 5      1.0        5.0      1.0       1.0       2.0     27
# 6      NaN        NaN      NaN       NaN       1.0      1
# 7      NaN        1.0      1.0       1.0       NaN     11
# 8      5.0        2.0      1.0       2.0       5.0     34
# 9      NaN        NaN      1.0       NaN       NaN      1
# 10     1.0        4.0      1.0       NaN       1.0     14
# 11     NaN        2.0      NaN       1.0       NaN      7
# 12     5.0        1.0      5.0       3.0       5.0     48
# 13     2.0        1.0      1.0       NaN       1.0      6
# 14     NaN        NaN      NaN       1.0       2.0      5
# 15    16.0       10.0     20.0      23.0      14.0    202
# 16     NaN        2.0      2.0       1.0       1.0      9
# 17     NaN        1.0      NaN       NaN       NaN      7
# 18     NaN        1.0      NaN       NaN       1.0      2
# 19     NaN        2.0      NaN       1.0       1.0      9
# 20     1.0        1.0      2.0       1.0       NaN     13
# 21     NaN        NaN      1.0       NaN       NaN      2
# 22     NaN        2.0      1.0       1.0       2.0     14
# 23     1.0        1.0      NaN       NaN       NaN      5
# 24     NaN        NaN      1.0       NaN       NaN      2
# 25     4.0        2.0      6.0       3.0       6.0     61
# 26     2.0        NaN      1.0       1.0       1.0      7
# 27     NaN        1.0      NaN       NaN       NaN      1
# 28     6.0        8.0      7.0      12.0       9.0    101
# 29     4.0        5.0      1.0       3.0       6.0     48
# 30     NaN        NaN      1.0       NaN       NaN      4
# 31     8.0        6.0      8.0      14.0      10.0     96
# 32     5.0        4.0      7.0      11.0       7.0     80
# 33     NaN        NaN      1.0       NaN       NaN      4
# 34     4.0        4.0      1.0       3.0       2.0     31
# 35     NaN        NaN      3.0       1.0       1.0     11
# 36     NaN        1.0      NaN       1.0       NaN      5
# 37     NaN        3.0      NaN       NaN       1.0      9
# 38     3.0        4.0      2.0       4.0       2.0     34
# 39     NaN        2.0      1.0       NaN       NaN      7
# 40     1.0        3.0      1.0       1.0       NaN     12
# 41     NaN        NaN      NaN       NaN       NaN      1
# 42     1.0        2.0      1.0       2.0       NaN     12
# 43     2.0        NaN      1.0       1.0       1.0     11
# 44     2.0        2.0      NaN       2.0       4.0     23
# 45     1.0        NaN      2.0       NaN       1.0      6
# 46     1.0        1.0      2.0       1.0       1.0      6
# 47     NaN        2.0      NaN       NaN       NaN      3
# 48     2.0        2.0      1.0       2.0       2.0     19
# 49     NaN        1.0      1.0       NaN       1.0      5
# 50     2.0        1.0      1.0       NaN       1.0     13
# 51     NaN        NaN      1.0       1.0       1.0      8
# 52     NaN        NaN      1.0       1.0       NaN      3
# 53     NaN        NaN      NaN       NaN       NaN      1

# %%
merged_data2 = pd.merge(dfFatalALCCountyTotal, county_data, on='County', how='left')

# %%
merged_data2
# Out:
#              County  January  February  March  April   May  June  July  \
# 0           Alameda      4.0       3.0    3.0    2.0   3.0   1.0   3.0
# 1            Amador      NaN       NaN    NaN    NaN   1.0   NaN   2.0
# 2             Butte      NaN       1.0    NaN    NaN   NaN   NaN   NaN
# 3         Calaveras      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 4            Colusa      NaN       NaN    1.0    NaN   NaN   NaN   NaN
# 5      Contra Costa      2.0       4.0    2.0    2.0   1.0   4.0   2.0
# 6         Del Norte      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 7         El Dorado      1.0       3.0    NaN    1.0   NaN   1.0   2.0
# 8            Fresno      NaN       7.0    1.0    3.0   1.0   3.0   4.0
# 9             Glenn      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 10         Humboldt      1.0       1.0    NaN    NaN   1.0   3.0   1.0
# 11         Imperial      NaN       1.0    1.0    1.0   1.0   NaN   NaN
# 12             Kern      6.0       5.0    NaN    4.0   4.0   5.0   5.0
# 13            Kings      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 14             Lake      NaN       NaN    NaN    NaN   1.0   1.0   NaN
# 15      Los Angeles     15.0      19.0   17.0   19.0  13.0  20.0  16.0
# 16           Madera      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 17            Marin      1.0       NaN    1.0    2.0   1.0   NaN   1.0
# 18         Mariposa      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 19        Mendocino      1.0       NaN    1.0    1.0   NaN   NaN   2.0
# 20           Merced      NaN       NaN    4.0    NaN   2.0   2.0   NaN
# 21             Mono      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 22         Monterey      1.0       NaN    1.0    2.0   1.0   2.0   1.0
# 23             Napa      1.0       NaN    NaN    NaN   NaN   1.0   1.0
# 24           Nevada      NaN       NaN    NaN    NaN   NaN   1.0   NaN
# 25           Orange      9.0       5.0    6.0    4.0   3.0   9.0   4.0
# 26           Placer      1.0       NaN    1.0    NaN   NaN   NaN   NaN
# 27           Plumas      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 28        Riverside     11.0       3.0    6.0    7.0  10.0  13.0   9.0
# 29       Sacramento      4.0       NaN    4.0    6.0   3.0   8.0   4.0
# 30       San Benito      NaN       NaN    NaN    NaN   1.0   1.0   1.0
# 31   San Bernardino      5.0       6.0    3.0    4.0  15.0   8.0   9.0
# 32        San Diego      5.0       7.0   10.0    6.0   7.0   5.0   6.0
# 33    San Francisco      NaN       1.0    NaN    NaN   1.0   1.0   NaN
# 34      San Joaquin      4.0       2.0    4.0    2.0   2.0   1.0   2.0
# 35  San Luis Obispo      NaN       1.0    1.0    NaN   NaN   1.0   3.0
# 36        San Mateo      NaN       2.0    NaN    1.0   NaN   NaN   NaN
# 37    Santa Barbara      2.0       NaN    1.0    NaN   NaN   2.0   NaN
# 38      Santa Clara      3.0       NaN    2.0    3.0   3.0   5.0   3.0
# 39       Santa Cruz      NaN       2.0    2.0    NaN   NaN   NaN   NaN
# 40           Shasta      1.0       1.0    1.0    NaN   NaN   3.0   NaN
# 41         Siskiyou      NaN       NaN    NaN    NaN   NaN   NaN   1.0
# 42           Solano      1.0       NaN    2.0    1.0   1.0   NaN   1.0
# 43           Sonoma      NaN       1.0    2.0    NaN   1.0   1.0   1.0
# 44       Stanislaus      NaN       3.0    3.0    2.0   2.0   1.0   2.0
# 45           Sutter      NaN       NaN    NaN    NaN   2.0   NaN   NaN
# 46           Tehama      NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 47          Trinity      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 48           Tulare      1.0       1.0    2.0    NaN   2.0   NaN   4.0
# 49         Tuolumne      1.0       NaN    NaN    NaN   1.0   NaN   NaN
# 50          Ventura      NaN       NaN    2.0    NaN   4.0   NaN   2.0
# 51             Yolo      1.0       NaN    1.0    1.0   2.0   NaN   NaN
# 52             Yuba      NaN       NaN    NaN    NaN   1.0   NaN   NaN
# 53             Inyo      NaN       NaN    NaN    NaN   NaN   NaN   1.0
#
#     August  September  October  November  December  Total   Latitude  \
# 0      4.0        2.0      2.0       NaN       1.0     28  37.609029
# 1      1.0        NaN      NaN       NaN       NaN      4  38.449089
# 2      3.0        1.0      2.0       1.0       1.0      9  39.651927
# 3      1.0        1.0      1.0       1.0       NaN      4  38.255818
# 4      NaN        NaN      NaN       NaN       NaN      1  39.146558
# 5      1.0        5.0      1.0       1.0       2.0     27  37.903481
# 6      NaN        NaN      NaN       NaN       1.0      1  41.726177
# 7      NaN        1.0      1.0       1.0       NaN     11  38.757414
# 8      5.0        2.0      1.0       2.0       5.0     34  36.729529
# 9      NaN        NaN      1.0       NaN       NaN      1  39.591277
# 10     1.0        4.0      1.0       NaN       1.0     14        NaN
# 11     NaN        2.0      NaN       1.0       NaN      7  33.030549
# 12     5.0        1.0      5.0       3.0       5.0     48  35.314570
# 13     2.0        1.0      1.0       NaN       1.0      6  36.078481
# 14     NaN        NaN      NaN       1.0       2.0      5  39.050541
# 15    16.0       10.0     20.0      23.0      14.0    202  34.053691
# 16     NaN        2.0      2.0       1.0       1.0      9  37.171626
# 17     NaN        1.0      NaN       NaN       NaN      7  38.040914
# 18     NaN        1.0      NaN       NaN       1.0      2  37.570148
# 19     NaN        2.0      NaN       1.0       1.0      9  39.317649
# 20     1.0        1.0      2.0       1.0       NaN     13  37.164154
# 21     NaN        NaN      1.0       NaN       NaN      2  37.953393
# 22     NaN        2.0      1.0       1.0       2.0     14  36.223108
# 23     1.0        1.0      NaN       NaN       NaN      5  38.297137
# 24     NaN        NaN      1.0       NaN       NaN      2  39.354033
# 25     4.0        2.0      6.0       3.0       6.0     61  33.750631
# 26     2.0        NaN      1.0       1.0       1.0      7  39.101206
# 27     NaN        1.0      NaN       NaN       NaN      1  39.943099
# 28     6.0        8.0      7.0      12.0       9.0    101  33.721999
# 29     4.0        5.0      1.0       3.0       6.0     48  38.581061
# 30     NaN        NaN      1.0       NaN       NaN      4  36.624809
# 31     8.0        6.0      8.0      14.0      10.0     96  34.825302
# 32     5.0        4.0      7.0      11.0       7.0     80  32.717420
# 33     NaN        NaN      1.0       NaN       NaN      4  37.779026
# 34     4.0        4.0      1.0       3.0       2.0     31  37.937290
# 35     NaN        NaN      3.0       1.0       1.0     11  35.354021
# 36     NaN        1.0      NaN       1.0       NaN      5  37.496904
# 37     NaN        3.0      NaN       NaN       1.0      9  34.422132
# 38     3.0        4.0      2.0       4.0       2.0     34  37.233325
# 39     NaN        2.0      1.0       NaN       NaN      7  37.050096
# 40     1.0        3.0      1.0       1.0       NaN     12  40.796512
# 41     NaN        NaN      NaN       NaN       NaN      1  41.686247
# 42     1.0        2.0      1.0       2.0       NaN     12  38.221894
# 43     2.0        NaN      1.0       1.0       1.0     11  38.511080
# 44     2.0        2.0      NaN       2.0       4.0     23  37.550087
# 45     1.0        NaN      2.0       NaN       1.0      6  38.950967
# 46     1.0        1.0      2.0       1.0       1.0      6  40.125133
# 47     NaN        2.0      NaN       NaN       NaN      3  40.605326
# 48     2.0        2.0      1.0       2.0       2.0     19  36.251647
# 49     NaN        1.0      1.0       NaN       1.0      5  38.056944
# 50     2.0        1.0      1.0       NaN       1.0     13  34.445825
# 51     NaN        NaN      1.0       1.0       1.0      8  38.718454
# 52     NaN        NaN      1.0       1.0       NaN      3  39.283975
# 53     NaN        NaN      NaN       NaN       NaN      1  36.559533
#
#      Longitude
# 0  -121.899142
# 1  -120.591102
# 2  -121.585844
# 3  -120.498149
# 4  -122.220956
# 5  -121.917535
# 6  -123.913280
# 7  -120.527613
# 8  -119.708861
# 9  -122.377866
# 10         NaN
# 11 -115.359567
# 12 -118.753822
# 13 -119.795634
# 14 -122.777656
# 15 -118.242766
# 16 -119.773799
# 17 -122.619964
# 18 -119.903659
# 19 -123.412640
# 20 -120.767860
# 21 -118.939876
# 22 -121.387742
# 23 -122.285529
# 24 -120.808984
# 25 -117.872231
# 26 -120.765061
# 27 -120.805952
# 28 -116.037247
# 29 -121.493895
# 30 -121.117738
# 31 -116.083314
# 32 -117.162772
# 33 -122.419906
# 34 -121.277372
# 35 -120.375716
# 36 -122.333057
# 37 -119.702667
# 38 -121.684635
# 39 -121.990590
# 40 -121.997919
# 41 -122.536012
# 42 -121.916355
# 43 -122.847339
# 44 -121.050143
# 45 -121.697088
# 46 -122.201553
# 47 -123.171268
# 48 -118.852583
# 49 -119.991935
# 50 -119.077936
# 51 -121.905900
# 52 -121.355682
# 53 -117.407471

# %%
gfd4 = gpd.GeoDataFrame(merged_data2, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(merged_data2.Latitude, merged_data2.Longitude))
gfd4.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Loop through each row in the merged dataset
for index, row in merged_data2.iterrows():
    county = row['County']
    latitude = row['Latitude']
    longitude = row['Longitude']
    value = row['Total']  # Replace 'Total' with the correct column name containing the values you want to visualize
    
    # If the latitude or longitude is NaN, skip this row
    if pd.i  snull(latitude) or pd.isnull(longitude):
        continue

# %%
import folium
import pandas as pd

california_map = folium.Map(location=[36.7783, -119.4179], zoom_start=6)

# Loop through each row in the merged dataset
for index, row in merged_data2.iterrows():
    county = row['County']
    latitude = row['Latitude']
    longitude = row['Longitude']
    value = row['Total']  
    # If the latitude or longitude is NaN, skip this row
    if pd.isnull(latitude) or pd.isnull(longitude):
        continue
    
    # Color code the counties based on the column values
if value < 5:
    color = 'yellow'
elif 5 <= value < 10:
    color = 'orange'
elif 10 <= value < 15:
    color = 'pink'
elif 15 <= value < 20:
    color = 'lightred'
elif 20 <= value < 30:
    color = 'red'
elif 30 <= value < 50:
    color = 'maroon'
elif 50 <= value < 100:
    color = 'brown'
else:
    color = 'black'
    
    # Add a marker for each county with a popup showing the county name and value
    folium.CircleMarker(
        location=[latitude, longitude],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"{county}: {value}"
    ).add_to(california_map)

# Save the map
california_map.save('county_map_Total.html')

# %%
import folium
import pandas as pd

california_map = folium.Map(location=[36.7783, -119.4179], zoom_start=6)

# Loop through each row in the merged dataset
for index, row in merged_data2.iterrows():
    county = row['County']
    latitude = row['Latitude']
    longitude = row['Longitude']
    value = row['Total']  
    # If the latitude or longitude is NaN, skip this row
    if pd.isnull(latitude) or pd.isnull(longitude):
        continue
    
    # Color code the counties based on the column values
    if value < 5:
        color = 'yellow'
    elif 5 <= value < 10:
        color = 'orange'
    elif 10 <= value < 15:
        color = 'pink'
    elif 15 <= value < 20:
        color = 'red'
    elif 20 <= value < 30:
        color = 'darkred'
    elif 30 <= value < 50:
        color = 'purple'
    elif 50 <= value < 100:
        color = 'brown'
    else:
        color = 'black'
    
    # Add a marker for each county with a popup showing the county name and value
    folium.CircleMarker(
        location=[latitude, longitude],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"{county}: {value}"
    ).add_to(california_map)

# Save the map
california_map.save('county_map_Total.html')

# %%
dfTypeAccidentAge2
# Out:
#     Age  Driver killed  Driver injured  Passenger Killed  Passenger Injured  \
# 0   0-4              0              14                 2                243
# 1     5              0               2                 1                 79
# 2     6              0               2                 1                 84
# 3     7              0               0                 1                 89
# 4     8              0               0                 1                 72
# 5     9              0               1                 3                 84
# 6    10              0               3                 1                103
# 7    11              0               0                 1                113
# 8    12              0               1                 1                 87
# 9    13              0               2                 3                 96
# 10   14              0               2                 2                 96
# 11   15              0              15                 6                131
# 12   16              1              39                 3                149
# 13   17              5             115                 6                168
# 14   18              3             263                 7                224
# 15   19              6             378                 5                228
# 16   20             12             429                 6                256
# 17   21             24             679                11                280
# 18   22             27             689                11                283
# 19   23             17             719                10                238
# 20   24             23             749                 6                239
# 21   25             37             711                 9                221
# 22   26             28             685                 5                200
# 23   27             18             659                 5                208
# 24   28             22             644                 8                186
# 25   29             22             586                 1                165
# 26   30             14             566                 4                141
# 27   31             16             497                 3                107
# 28   32             12             461                 3                125
# 29   33             19             446                 4                110
# 30   34             20             433                 2                 99
# 31   35             13             408                 5                 91
# 32   36             14             364                 2                 81
# 33   37             12             369                 0                 92
# 34   38             10             349                 5                 73
# 35   39              6             333                 1                 93
# 36   40             16             312                 2                 71
# 37   41              7             282                 5                 60
# 38   42              9             263                 3                 76
# 39   43              7             267                 0                 80
# 40   44             16             262                 1                 55
# 41   45              8             228                 1                 68
# 42   46              7             240                 0                 53
# 43   47             10             256                 1                 63
# 44   48              9             277                 1                 72
# 45   49             13             261                 1                 75
# 46   50              6             233                 2                 56
# 47   51              7             223                 1                 59
# 48   52              8             197                 4                 63
# 49   53              7             199                 1                 38
# 50   54              7             186                 1                 43
# 51   55             10             193                 2                 70
# 52   56              7             209                 1                 43
# 53   57             12             191                 2                 45
# 54   58             10             172                 0                 49
# 55   59             12             167                 3                 40
#
#     Pedestrian Killed  Pedestrian Injured  Bicyclist Killed  \
# 0                   2                  15                 0
# 1                   0                   4                 0
# 2                   0                   1                 0
# 3                   0                   1                 0
# 4                   0                   2                 0
# 5                   0                   2                 0
# 6                   1                   4                 0
# 7                   0                   5                 0
# 8                   0                   4                 0
# 9                   1                  11                 0
# 10                  1                  10                 0
# 11                  0                  20                 0
# 12                  1                  12                 0
# 13                  2                  19                 0
# 14                  0                  22                 0
# 15                  4                  22                 1
# 16                  3                  22                 0
# 17                  5                  30                 0
# 18                  8                  46                 1
# 19                  3                  37                 0
# 20                  4                  40                 1
# 21                  9                  42                 1
# 22                  7                  41                 0
# 23                  4                  45                 1
# 24                  6                  53                 1
# 25                  4                  37                 0
# 26                 13                  37                 3
# 27                 11                  38                 1
# 28                  5                  38                 1
# 29                  5                  32                 0
# 30                  5                  36                 1
# 31                  8                  39                 0
# 32                  4                  30                 2
# 33                  2                  21                 0
# 34                  4                  32                 0
# 35                  5                  26                 1
# 36                  5                  25                 0
# 37                  7                  23                 1
# 38                  4                  29                 1
# 39                 10                  18                 1
# 40                  1                  24                 2
# 41                  8                  25                 0
# 42                  6                  25                 0
# 43                  7                  28                 0
# 44                  4                  21                 0
# 45                  4                  26                 2
# 46                  4                  24                 0
# 47                  7                  25                 0
# 48                  8                  12                 1
# 49                  6                  18                 0
# 50                  8                  33                 0
# 51                  2                  30                 0
# 52                 11                  27                 2
# 53                  2                  29                 1
# 54                  4                  29                 0
# 55                  8                  26                 0
#
#     Bicyclist Injured  Motorcyclist Killed  Motorcyclist Injured
# 0                   0                    0                     2
# 1                   0                    0                     0
# 2                   2                    0                     1
# 3                   1                    0                     2
# 4                   3                    0                     1
# 5                   0                    0                     2
# 6                   1                    1                     1
# 7                   1                    0                     1
# 8                   6                    0                     0
# 9                   2                    0                     0
# 10                  6                    0                     0
# 11                 10                    0                     2
# 12                  4                    0                     1
# 13                  8                    0                     3
# 14                  6                    0                     5
# 15                  9                    1                     8
# 16                  5                    2                     9
# 17                 10                    4                    20
# 18                 10                    6                    28
# 19                 14                    3                    15
# 20                 10                    4                    36
# 21                 14                   10                    25
# 22                  8                    7                    34
# 23                 24                    5                    33
# 24                 16                    6                    29
# 25                 11                    6                    31
# 26                 13                    2                    40
# 27                  8                    7                    32
# 28                  6                    5                    23
# 29                 12                    4                    23
# 30                  6                    3                    20
# 31                  8                    3                    23
# 32                 10                    5                    31
# 33                 12                    3                    22
# 34                 11                    5                    18
# 35                 13                    3                    15
# 36                 10                    2                    26
# 37                 16                    5                    22
# 38                  7                    1                    16
# 39                 10                    2                    22
# 40                  7                    2                     8
# 41                  7                    2                    11
# 42                  8                    2                    10
# 43                 11                    5                    13
# 44                  9                    4                    17
# 45                 16                    4                    15
# 46                 14                    1                    15
# 47                 11                    2                    10
# 48                 12                    2                    13
# 49                 11                    3                    14
# 50                 14                    3                     7
# 51                 14                    2                    11
# 52                  6                    2                    16
# 53                  7                    4                    19
# 54                 13                    4                    14
# 55                  9                    1                     8

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
dfTypeAccidentAge2 = pd.read_csv("Book1kjwbcj.csv")

# %%
# Check lengths of lists
print("Length of 'Age':", len(data['Age']))
print("Length of 'Driver killed':", len(data['Driver killed']))
# Continue checking lengths for other columns
# Out:
# Length of 'Age': 58
# Length of 'Driver killed': 60

# %%
# Plotting
plt.figure(figsize=(12, 8))
dfTypeAccidentAge2.plot(kind='bar', stacked=True, colormap='viridis')
plt.xlabel('Count')
plt.ylabel('Age')
plt.title('Traffic Casualties by Age Group')
plt.legend(title='Casualty Type')
plt.show()

# %%
plt.figure(figsize=(12, 8))
dfTypeAccidentAge.plot(kind='bar', stacked=True, colormap='viridis', width=0.8)  # Adjust the width parameter
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Traffic Casualties by Age Group')
plt.legend(title='Casualty Type')
plt.show()

# %%
print(dfTypeAccidentAge.columns)
# Out:
# Index(['Driver killed', 'Driver injured', 'Passenger Killed',
#        'Passenger Injured', 'Pedestrian Killed', 'Pedestrian Injured',
#        'Bicyclist Killed', 'Bicyclist Injured', 'Motorcyclist Killed',
#        'Motorcyclist Injured'],
#       dtype='object')

# %%
dfAgeVictim.set_index('Age', inplace=True)

# Plot the bar chart
dfAgeVictim.plot(kind='bar', figsize=(15, 10))
plt.xlabel('Age')
plt.ylabel('Number of Individuals Killed')
plt.title('Comparison of Alcohol impaired Drivers Killed and Passengers Killed by Age')
plt.xticks(rotation=90)
plt.legend(title='Type of Individual', labels=['Drivers Killed', 'Passengers Killed'])
plt.show()
