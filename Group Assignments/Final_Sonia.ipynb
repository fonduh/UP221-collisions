# %%
# Final - Sonia Garfinkel

# Crash! : Collisions in City of LA
# Research Question: 
# What are some contributing factors towards patterns of collision in Los Angeles?:
# Road characteristics
#Commute time/mode
#Time of day of collision
#Comparing areas and regions within greater Los Angeles 
#Substance Abuse
#Demographic characteristics of dataset

# 337 Fatalities on LA City streets in 2023

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import folium

# %%
col = pd.read_csv('2020_Collisions.csv')

# %%
col.sample(10)
#shows a sample of 10
# Out:
#        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 31465  200514532     9/24/2020     9/24/2020           1815        5
# 4864   201509105     4/23/2020     4/23/2020           1610       15
# 40206  201615357     12/5/2020     12/5/2020            800       16
# 34332  201417235     9/16/2020     9/15/2020           2350       14
# 25975  201822783    12/28/2020    12/28/2020           1900       18
# 38386  201112791     8/23/2020     8/23/2020            900       11
# 17143  201410986     5/16/2020     5/16/2020           1410       14
# 16990  201811061     5/13/2020     5/13/2020           1805       18
# 36726  200816785    11/23/2020    11/23/2020           1130        8
# 29904  201814972      8/2/2020      7/2/2020           1600       18
#
#          Area Name  Reporting District  Crime Code Crime Code Description  \
# 31465       Harbor                 562         997      TRAFFIC COLLISION
# ...

# %%
col = gpd.GeoDataFrame(col, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(col.Longitude, col.Latitude))

# %%
#Mapping the 2020 traffic collisions data onto the map

fig, ax = plt.subplots(figsize=(12,12))

#specifying the data marking options
ax = col.clip([-189,18,-66,71]).plot(ax=ax, 
        marker='*',
        markersize=3,
        color='green')

ax.axis('off')

#set the title
ax.set_title('Traffic Collisions in LA in 2020')

ctx.add_basemap(ax, crs=4326)

#below shows all of the 2020 traffic collisions in LA

# %%
# List of desired column names
desired_columns = ['Victim Age']

#Subset based on desired columns
col[desired_columns].sample(5)
# Out:
#        Victim Age
# 11732        37.0
# 14296        36.0
# 42309        22.0
# 26869        63.0
# 24271         NaN

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['Victim Age']
values = col[desired_columns]

# Create bar plot
plt.bar(victim age, count)

# Add labels and title
plt.xlabel('Victim Age')
plt.ylabel('Counts')
plt.title('Victim Age')

# Show plot
plt.show()
# Out:
#   Cell In[16], line 8
#     plt.bar(victim age, count)
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# This is not working to show a bar graph

# %%
# I created the storymap
