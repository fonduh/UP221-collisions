# %%
##Research Question: In the City of Los Angeles, what do the traffic collisions look like in 2020, and how do they compare to 2010?

# %%
from PIL import Image
from IPython.display import display

# %%
#Collsions that involved drinking

# %%
img = Image.open('HBD..png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=812x616>

# %%
#La Traffic Collisions by Age in 2020

# %%
img = Image.open('Age.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=682x574>

# %%
#Road Conditions in LA

# %%
img = Image.open('Road.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=460x559>

# %%
img = Image.open('Road2.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=605x259>

# %%
#Bad example of collsions by date reported

# %%
img = Image.open('Bad.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=619x543>
